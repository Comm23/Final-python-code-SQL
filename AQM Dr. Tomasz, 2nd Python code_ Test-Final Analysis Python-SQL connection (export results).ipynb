# %%
import pandas as pd
import numpy as np
import random
import itertools
import statsmodels.api as sm

# %%
# Charger le fichier Excel dans un DataFrame
df = pd.read_excel('regression_results.xlsx', sheet_name=None)

# Accéder aux données du DataFrame
for sheet_name, sheet_df in df.items():
    print(f"Feuille : {sheet_name}")
    print(sheet_df)
    print()
# Out:
# Feuille : WTI
#       Unnamed: 0                             Variables_explicatives  \
# 0              0                                     ['RUSSIA GDP']
# 1              1                         ['USA INFLATION RATE CPI']
# 2              2                             ['USA INTEREST RATES']
# 3              3                      ['USA INDUSTRIAL PRODUCTION']
# 4              4                               ['RUSSIA RTS INDEX']
# ...          ...                                                ...
# 8186        8186  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8187        8187  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8188        8188  ['RUSSIA GDP', 'USA INTEREST RATES', 'USA INDU...
# 8189        8189  ['USA INFLATION RATE CPI', 'USA INTEREST RATES...
# 8190        8190  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
#
#                                            Coefficients  \
# 0     const         65.080373\nRUSSIA GDP    20.0484...
# 1     const                     51.159095\nUSA INFLA...
# 2     const                 60.14698\nUSA INTEREST R...
# 3     const                        65.031657\nUSA IN...
# 4     const               57.813343\nRUSSIA RTS INDE...
# ...                                                 ...
# 8186  const                    -84.755985\nRUSSIA GD...
# 8187  const                       -84.469788\nRUSSIA...
# 8188  const                       -95.328284\nRUSSIA...
# 8189  const                       -85.262363\nUSA IN...
# 8190  const                       -85.230668\nRUSSIA...
#
#                                        Erreurs_standard  \
# 0     const          1.985936\nRUSSIA GDP    57.3994...
# 1     const                     2.451928\nUSA INFLAT...
# 2     const                 2.643297\nUSA INTEREST R...
# 3     const                        1.985306\nUSA IND...
# 4     const               10.434068\nRUSSIA RTS INDE...
# ...                                                 ...
# 8186  const                     14.646950\nRUSSIA GD...
# 8187  const                        14.574918\nRUSSIA...
# 8188  const                        15.900458\nRUSSIA...
# 8189  const                        14.393933\nUSA IN...
# 8190  const                        14.437454\nRUSSIA...
#
#                                                 P-value  Autocorr_test  \
# 0     const         4.264747e-61\nRUSSIA GDP    7.27...       0.087943
# 1     const                     2.092214e-41\nUSA IN...       0.133153
# 2     const                 5.691490e-45\nUSA INTERE...       0.095709
# 3     const                        4.465239e-61\nUSA...       0.091202
# 4     const               1.858954e-07\nRUSSIA RTS I...       0.091249
# ...                                                 ...            ...
# 8186  const                     7.237336e-08\nRUSSIA...       0.937196
# 8187  const                        6.949286e-08\nRUS...       0.860245
# 8188  const                        2.789536e-08\nRUS...       0.862059
# 8189  const                        3.879451e-08\nUSA...       0.948978
# 8190  const                        4.335603e-08\nRUS...       0.945473
#
#       Hetero_test  Multicollinearity_Fstat  Multicollinearity_pvalue  \
# 0        0.011080                 0.121996              7.275021e-01
# 1        0.172055                57.547790              8.352978e-12
# 2        0.295572                 7.384881              7.568346e-03
# 3        0.107446                 0.252669              6.161387e-01
# 4        0.224780                 0.500946              4.804804e-01
# ...           ...                      ...                       ...
# 8186     0.562125                30.413644              4.485158e-29
# 8187     0.244235                30.778591              2.772556e-29
# 8188     0.300389                23.843466              5.893704e-25
# 8189     0.472172                31.818539              7.204842e-30
# 8190     0.413872                29.222028              3.507588e-29
#
#       Adjusted_R_squared
# 0              -0.007433
# 1               0.322122
# 2               0.050922
# 3              -0.006320
# 4              -0.004211
# ...                  ...
# 8186            0.747862
# 8187            0.750180
# 8188            0.697295
# 8189            0.756558
# 8190            0.755087
#
# [8191 rows x 10 columns]
#
# Feuille : Henry Hub Nat Gas
#       Unnamed: 0                             Variables_explicatives  \
# 0              0                                     ['RUSSIA GDP']
# 1              1                         ['USA INFLATION RATE CPI']
# 2              2                             ['USA INTEREST RATES']
# 3              3                      ['USA INDUSTRIAL PRODUCTION']
# 4              4                               ['RUSSIA RTS INDEX']
# ...          ...                                                ...
# 8186        8186  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8187        8187  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8188        8188  ['RUSSIA GDP', 'USA INTEREST RATES', 'USA INDU...
# 8189        8189  ['USA INFLATION RATE CPI', 'USA INTEREST RATES...
# 8190        8190  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
#
#                                            Coefficients  \
# 0     const         3.382679\nRUSSIA GDP    3.520054...
# 1     const                     3.086589\nUSA INFLAT...
# 2     const                 3.429380\nUSA INTEREST R...
# 3     const                        3.378399\nUSA IND...
# 4     const               2.231716\nRUSSIA RTS INDEX...
# ...                                                 ...
# 8186  const                    -4.971324\nRUSSIA GDP...
# 8187  const                       -4.905386\nRUSSIA ...
# 8188  const                       -4.809665\nRUSSIA ...
# 8189  const                       -5.014437\nUSA INF...
# 8190  const                       -5.013137\nRUSSIA ...
#
#                                        Erreurs_standard  \
# 0     const         0.126160\nRUSSIA GDP    3.646409...
# 1     const                     0.187186\nUSA INFLAT...
# 2     const                 0.173560\nUSA INTEREST R...
# 3     const                        0.126627\nUSA IND...
# 4     const               0.657773\nRUSSIA RTS INDEX...
# ...                                                 ...
# 8186  const                     1.389972\nRUSSIA GDP...
# 8187  const                        1.410940\nRUSSIA ...
# 8188  const                        1.362069\nRUSSIA ...
# 8189  const                        1.367789\nUSA INF...
# 8190  const                        1.373804\nRUSSIA ...
#
#                                                 P-value  Autocorr_test  \
# 0     const         5.016790e-52\nRUSSIA GDP    3.36...       0.247384
# 1     const                     2.072923e-32\nUSA IN...       0.253065
# 2     const                 3.127104e-39\nUSA INTERE...       0.245249
# 3     const                        8.291935e-52\nUSA...       0.246417
# 4     const               0.000942\nRUSSIA RTS INDEX...       0.255979
# ...                                                 ...            ...
# 8186  const                     0.000524\nRUSSIA GDP...       0.786992
# 8187  const                        0.000735\nRUSSIA ...       0.726204
# 8188  const                        0.000612\nRUSSIA ...       0.779112
# 8189  const                        3.852721e-04\nUSA...       0.802607
# 8190  const                        0.000410\nRUSSIA ...       0.802113
#
#       Hetero_test  Multicollinearity_Fstat  Multicollinearity_pvalue  \
# 0        0.591155                 0.931897              3.363447e-01
# 1        0.087997                 4.389906              3.829099e-02
# 2        0.010371                 0.174348              6.770353e-01
# 3        0.570230                 0.113535              7.367537e-01
# 4        0.314758                 3.160385              7.802131e-02
# ...           ...                      ...                       ...
# 8186     0.004683                 8.829026              1.641135e-11
# 8187     0.005578                 8.294761              7.227400e-11
# 8188     0.017122                 9.223870              5.613581e-12
# 8189     0.007323                 9.413821              3.373186e-12
# 8190     0.007885                 8.618980              1.038402e-11
#
#       Adjusted_R_squared
# 0              -0.000573
# 1               0.027698
# 2              -0.006987
# 3              -0.007505
# 4               0.017831
# ...                  ...
# 8186            0.441179
# 8187            0.423832
# 8188            0.453342
# 8189            0.459007
# 8190            0.454245
#
# [8191 rows x 10 columns]
#
# Feuille : Corn
#       Unnamed: 0                             Variables_explicatives  \
# 0              0                                     ['RUSSIA GDP']
# 1              1                         ['USA INFLATION RATE CPI']
# 2              2                             ['USA INTEREST RATES']
# 3              3                      ['USA INDUSTRIAL PRODUCTION']
# 4              4                               ['RUSSIA RTS INDEX']
# ...          ...                                                ...
# 8186        8186  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8187        8187  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8188        8188  ['RUSSIA GDP', 'USA INTEREST RATES', 'USA INDU...
# 8189        8189  ['USA INFLATION RATE CPI', 'USA INTEREST RATES...
# 8190        8190  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
#
#                                            Coefficients  \
# 0     const         446.487326\nRUSSIA GDP   -482.53...
# 1     const                     464.034008\nUSA INFL...
# 2     const                 466.054025\nUSA INTEREST...
# 3     const                        446.827072\nUSA I...
# 4     const               484.312088\nRUSSIA RTS IND...
# ...                                                 ...
# 8186  const                    -659.170895\nRUSSIA G...
# 8187  const                       -659.685889\nRUSSI...
# 8188  const                       -600.348460\nRUSSI...
# 8189  const                       -662.840434\nUSA I...
# 8190  const                       -662.258261\nRUSSI...
#
#                                        Erreurs_standard  \
# 0     const          11.639619\nRUSSIA GDP    336.41...
# 1     const                     17.544596\nUSA INFLA...
# 2     const                 15.892416\nUSA INTEREST ...
# 3     const                        11.742233\nUSA IN...
# 4     const               61.684258\nRUSSIA RTS INDE...
# ...                                                 ...
# 8186  const                      98.552563\nRUSSIA G...
# 8187  const                         97.130155\nRUSSI...
# 8188  const                        105.281893\nRUSSI...
# 8189  const                        98.016907\nUSA IN...
# 8190  const                         97.267850\nRUSSI...
#
#                                                 P-value  Autocorr_test  \
# 0     const         1.775310e-68\nRUSSIA GDP    1.54...       0.109216
# 1     const                     2.001282e-51\nUSA IN...       0.110210
# 2     const                 5.056499e-56\nUSA INTERE...       0.113492
# 3     const                        4.262141e-68\nUSA...       0.109926
# 4     const               2.094711e-12\nRUSSIA RTS I...       0.111296
# ...                                                 ...            ...
# 8186  const                     1.062003e-09\nRUSSIA...       0.838305
# 8187  const                        6.449987e-10\nRUS...       0.782745
# 8188  const                        1.058901e-07\nRUS...       0.755214
# 8189  const                        7.431143e-10\nUSA...       0.774451
# 8190  const                        6.128655e-10\nRUS...       0.791824
#
#       Hetero_test  Multicollinearity_Fstat  Multicollinearity_pvalue  \
# 0        0.938801                 2.057278              1.541254e-01
# 1        0.017499                 1.709576              1.935822e-01
# 2        0.307051                 3.105003              8.064160e-02
# 3        0.578676                 0.023748              8.777919e-01
# 4        0.493288                 0.381924              5.377662e-01
# ...           ...                      ...                       ...
# 8186     0.006594                21.414622              3.132733e-23
# 8187     0.083151                22.290019              7.234131e-24
# 8188     0.006359                17.172639              7.052012e-20
# 8189     0.007417                21.754608              1.764682e-23
# 8190     0.012856                20.596226              2.403961e-23
#
#       Adjusted_R_squared
# 0               0.008806
# 1               0.005927
# 2               0.017382
# 3              -0.008272
# 4              -0.005221
# ...                  ...
# 8186            0.673055
# 8187            0.682226
# 8188            0.619895
# 8189            0.676679
# 8190            0.681606
#
# [8191 rows x 10 columns]
#
# Feuille : Gold
#       Unnamed: 0                             Variables_explicatives  \
# 0              0                                     ['RUSSIA GDP']
# 1              1                         ['USA INFLATION RATE CPI']
# 2              2                             ['USA INTEREST RATES']
# 3              3                      ['USA INDUSTRIAL PRODUCTION']
# 4              4                               ['RUSSIA RTS INDEX']
# ...          ...                                                ...
# 8186        8186  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8187        8187  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8188        8188  ['RUSSIA GDP', 'USA INTEREST RATES', 'USA INDU...
# 8189        8189  ['USA INFLATION RATE CPI', 'USA INTEREST RATES...
# 8190        8190  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
#
#                                            Coefficients  \
# 0     const         1446.062215\nRUSSIA GDP   -1085....
# 1     const                     1579.721148\nUSA INF...
# 2     const                 1546.361352\nUSA INTERES...
# 3     const                        1447.221197\nUSA ...
# 4     const               2047.744425\nRUSSIA RTS IN...
# ...                                                 ...
# 8186  const                      868.273590\nRUSSIA ...
# 8187  const                         874.368064\nRUSS...
# 8188  const                        1021.185352\nRUSS...
# 8189  const                        859.051118\nUSA I...
# 8190  const                         861.883480\nRUSS...
#
#                                        Erreurs_standard  \
# 0     const          24.696558\nRUSSIA GDP    713.80...
# 1     const                     33.786013\nUSA INFLA...
# 2     const                 31.475423\nUSA INTEREST ...
# 3     const                        24.931768\nUSA IN...
# 4     const               118.523814\nRUSSIA RTS IND...
# ...                                                 ...
# 8186  const                     218.270662\nRUSSIA G...
# 8187  const                        218.617536\nRUSSI...
# 8188  const                        240.449125\nRUSSI...
# 8189  const                        227.474840\nUSA I...
# 8190  const                        215.923309\nRUSSI...
#
#                                                 P-value  Autocorr_test  \
# 0     const         4.734974e-89\nRUSSIA GDP    1.31...       0.064452
# 1     const                     5.355630e-78\nUSA IN...       0.074755
# 2     const                 2.066498e-80\nUSA INTERE...       0.068936
# 3     const                        1.274175e-88\nUSA...       0.056462
# 4     const               4.167933e-34\nRUSSIA RTS I...       0.104651
# ...                                                 ...            ...
# 8186  const                     1.267160e-04\nRUSSIA...       0.457496
# 8187  const                        1.170827e-04\nRUS...       0.413855
# 8188  const                        4.635099e-05\nRUS...       0.500909
# 8189  const                        0.000262\nUSA INF...       0.413091
# 8190  const                        1.211668e-04\nRUS...       0.445854
#
#        Hetero_test  Multicollinearity_Fstat  Multicollinearity_pvalue  \
# 0     2.074963e-03                 2.311304              1.311113e-01
# 1     7.276201e-06                27.631390              6.617681e-07
# 2     1.487273e-07                21.287466              1.011639e-05
# 3     4.494006e-01                 0.107605              7.434693e-01
# 4     6.105564e-01                26.655888              9.971951e-07
# ...            ...                      ...                       ...
# 8186  3.211948e-03                18.979803              2.301400e-21
# 8187  4.450362e-03                18.874008              2.795737e-21
# 8188  2.523354e-03                13.648407              1.101668e-16
# 8189  5.809141e-02                16.774295              1.544404e-19
# 8190  9.084124e-03                18.166512              2.122271e-21
#
#       Adjusted_R_squared
# 0               0.010899
# 1               0.182868
# 2               0.145652
# 3              -0.007556
# 4               0.177358
# ...                  ...
# 8186            0.644519
# 8187            0.643166
# 8188            0.560530
# 8189            0.614002
# 8190            0.652214
#
# [8191 rows x 10 columns]
#
# Feuille : Sugar 11
#       Unnamed: 0                             Variables_explicatives  \
# 0              0                                     ['RUSSIA GDP']
# 1              1                         ['USA INFLATION RATE CPI']
# 2              2                             ['USA INTEREST RATES']
# 3              3                      ['USA INDUSTRIAL PRODUCTION']
# 4              4                               ['RUSSIA RTS INDEX']
# ...          ...                                                ...
# 8186        8186  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8187        8187  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8188        8188  ['RUSSIA GDP', 'USA INTEREST RATES', 'USA INDU...
# 8189        8189  ['USA INFLATION RATE CPI', 'USA INTEREST RATES...
# 8190        8190  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
#
#                                            Coefficients  \
# 0     const         15.632888\nRUSSIA GDP    -6.4988...
# 1     const                     15.559990\nUSA INFLA...
# 2     const                 15.613968\nUSA INTEREST ...
# 3     const                        15.648874\nUSA IN...
# 4     const               13.191233\nRUSSIA RTS INDE...
# ...                                                 ...
# 8186  const                     -7.679063\nRUSSIA GD...
# 8187  const                        -7.726056\nRUSSIA...
# 8188  const                       -6.337662\nRUSSIA ...
# 8189  const                       -7.744758\nUSA INF...
# 8190  const                        -7.732251\nRUSSIA...
#
#                                        Erreurs_standard  \
# 0     const         0.296121\nRUSSIA GDP    8.558767...
# 1     const                     0.446685\nUSA INFLAT...
# 2     const                 0.407053\nUSA INTEREST R...
# 3     const                        0.29536\nUSA INDU...
# 4     const               1.545167\nRUSSIA RTS INDEX...
# ...                                                 ...
# 8186  const                      3.174150\nRUSSIA GD...
# 8187  const                         3.157180\nRUSSIA...
# 8188  const                         3.278331\nRUSSIA...
# 8189  const                        3.175603\nUSA INF...
# 8190  const                         3.173375\nRUSSIA...
#
#                                                 P-value  Autocorr_test  \
# 0     const         6.153684e-84\nRUSSIA GDP    4.49...       0.141574
# 1     const                     6.180720e-64\nUSA IN...       0.139169
# 2     const                 1.779053e-68\nUSA INTERE...       0.139198
# 3     const                        4.095348e-84\nUSA...       0.160754
# 4     const               5.551128e-14\nRUSSIA RTS I...       0.150920
# ...                                                 ...            ...
# 8186  const                     0.017239\nRUSSIA GDP...       0.625297
# 8187  const                        0.016027\nRUSSIA ...       0.603727
# 8188  const                        0.055854\nRUSSIA ...       0.560587
# 8189  const                        0.016380\nUSA INF...       0.603080
# 8190  const                        0.016492\nRUSSIA ...       0.604204
#
#       Hetero_test  Multicollinearity_Fstat  Multicollinearity_pvalue  \
# 0        0.056512                 0.576573              4.491731e-01
# 1        0.020124                 0.054928              8.151061e-01
# 2        0.093069                 0.007595              9.307011e-01
# 3        0.865893                 1.244566              2.668597e-01
# 4        0.072465                 2.601876              1.094086e-01
# ...           ...                      ...                       ...
# 8186     0.120417                 9.774761              1.296807e-12
# 8187     0.125467                 9.964455              7.894918e-13
# 8188     0.018895                 8.283592              7.457778e-11
# 8189     0.143769                 9.762266              1.340096e-12
# 8190     0.122895                 9.112698              2.570201e-12
#
#       Adjusted_R_squared
# 0              -0.003571
# 1              -0.008005
# 2              -0.008410
# 3               0.002051
# 4               0.013282
# ...                  ...
# 8186            0.469454
# 8187            0.474784
# 8188            0.423458
# 8189            0.469099
# 8190            0.469851
#
# [8191 rows x 10 columns]
#
# Feuille : Cocoa
#       Unnamed: 0                             Variables_explicatives  \
# 0              0                                     ['RUSSIA GDP']
# 1              1                         ['USA INFLATION RATE CPI']
# 2              2                             ['USA INTEREST RATES']
# 3              3                      ['USA INDUSTRIAL PRODUCTION']
# 4              4                               ['RUSSIA RTS INDEX']
# ...          ...                                                ...
# 8186        8186  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8187        8187  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8188        8188  ['RUSSIA GDP', 'USA INTEREST RATES', 'USA INDU...
# 8189        8189  ['USA INFLATION RATE CPI', 'USA INTEREST RATES...
# 8190        8190  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
#
#                                            Coefficients  \
# 0     const         2569.737703\nRUSSIA GDP   -1631....
# 1     const                     2438.557935\nUSA INF...
# 2     const                 2713.313832\nUSA INTERES...
# 3     const                        2571.154517\nUSA ...
# 4     const               2080.702947\nRUSSIA RTS IN...
# ...                                                 ...
# 8186  const                     2381.509851\nRUSSIA ...
# 8187  const                        2433.524341\nRUSS...
# 8188  const                        2083.519163\nRUSS...
# 8189  const                        2383.532458\nUSA ...
# 8190  const                        2381.316076\nRUSS...
#
#                                        Erreurs_standard  \
# 0     const          33.609681\nRUSSIA GDP    971.41...
# 1     const                     48.516482\nUSA INFLA...
# 2     const                 42.533469\nUSA INTEREST ...
# 3     const                        34.016219\nUSA IN...
# 4     const               172.960536\nRUSSIA RTS IND...
# ...                                                 ...
# 8186  const                      317.041277\nRUSSIA ...
# 8187  const                         359.525014\nRUSS...
# 8188  const                         377.242350\nRUSS...
# 8189  const                        322.400626\nUSA I...
# 8190  const                         318.572537\nRUSS...
#
#                                                 P-value  Autocorr_test  \
# 0     const         2.260696e-102\nRUSSIA GDP     9....       0.280444
# 1     const                     1.582634e-81\nUSA IN...       0.311496
# 2     const                 2.612365e-93\nUSA INTERE...       0.326744
# 3     const                        8.520853e-102\nUS...       0.276554
# 4     const               3.038653e-22\nRUSSIA RTS I...       0.317483
# ...                                                 ...            ...
# 8186  const                     1.859354e-11\nRUSSIA...       0.897844
# 8187  const                        7.211303e-10\nRUS...       0.883403
# 8188  const                        2.357178e-07\nRUS...       0.791340
# 8189  const                        3.360202e-11\nUSA...       0.907924
# 8190  const                        2.325965e-11\nRUS...       0.896748
#
#       Hetero_test  Multicollinearity_Fstat  Multicollinearity_pvalue  \
# 0        0.004775                 2.819230              9.578725e-02
# 1        0.131946                13.351741              3.865928e-04
# 2        0.193694                23.866272              3.280406e-06
# 3        0.980588                 0.004212              9.483617e-01
# 4        0.325006                 8.339415              4.616049e-03
# ...           ...                      ...                       ...
# 8186     0.472013                15.675337              1.425143e-18
# 8187     0.368347                10.194905              4.344484e-13
# 8188     0.242702                 8.133469              1.138807e-10
# 8189     0.277728                14.870400              7.694025e-18
# 8190     0.491167                14.334614              5.805385e-18
#
#       Adjusted_R_squared
# 0               0.015057
# 1               0.094036
# 2               0.161182
# 3              -0.008439
# 4               0.058093
# ...                  ...
# 8186            0.596752
# 8187            0.481117
# 8188            0.418382
# 8189            0.583107
# 8190            0.592954
#
# [8191 rows x 10 columns]
#
# Feuille : Live Cattle
#       Unnamed: 0                             Variables_explicatives  \
# 0              0                                     ['RUSSIA GDP']
# 1              1                         ['USA INFLATION RATE CPI']
# 2              2                             ['USA INTEREST RATES']
# 3              3                      ['USA INDUSTRIAL PRODUCTION']
# 4              4                               ['RUSSIA RTS INDEX']
# ...          ...                                                ...
# 8186        8186  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8187        8187  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8188        8188  ['RUSSIA GDP', 'USA INTEREST RATES', 'USA INDU...
# 8189        8189  ['USA INFLATION RATE CPI', 'USA INTEREST RATES...
# 8190        8190  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
#
#                                            Coefficients  \
# 0     const         128.232267\nRUSSIA GDP    145.92...
# 1     const                     118.502945\nUSA INFL...
# 2     const                 132.650349\nUSA INTEREST...
# 3     const                        128.042228\nUSA I...
# 4     const               70.918430\nRUSSIA RTS INDE...
# ...                                                 ...
# 8186  const                      11.666513\nRUSSIA G...
# 8187  const                         12.011971\nRUSSI...
# 8188  const                          1.015199\nRUSSI...
# 8189  const                        11.198371\nUSA IN...
# 8190  const                         11.376013\nRUSSI...
#
#                                        Erreurs_standard  \
# 0     const          1.670585\nRUSSIA GDP    48.2848...
# 1     const                     2.326304\nUSA INFLAT...
# 2     const                 2.298244\nUSA INTEREST R...
# 3     const                        1.723010\nUSA IND...
# 4     const               7.383113\nRUSSIA RTS INDEX...
# ...                                                 ...
# 8186  const                     13.176861\nRUSSIA GD...
# 8187  const                        13.219909\nRUSSIA...
# 8188  const                        14.842270\nRUSSIA...
# 8189  const                        13.874585\nUSA IN...
# 8190  const                        13.124487\nRUSSIA...
#
#                                                 P-value  Autocorr_test  \
# 0     const         1.435677e-102\nRUSSIA GDP     3....       0.159446
# 1     const                     3.489348e-82\nUSA IN...       0.170068
# 2     const                 2.436681e-88\nUSA INTERE...       0.145172
# 3     const                        6.069876e-101\nUS...       0.163388
# 4     const               1.726469e-16\nRUSSIA RTS I...       0.305704
# ...                                                 ...            ...
# 8186  const                     3.779378e-01\nRUSSIA...       0.893971
# 8187  const                        3.655889e-01\nRUS...       0.916584
# 8188  const                        9.455956e-01\nRUS...       0.765748
# 8189  const                        4.213913e-01\nUSA...       0.797016
# 8190  const                        3.880217e-01\nRUS...       0.863314
#
#       Hetero_test  Multicollinearity_Fstat  Multicollinearity_pvalue  \
# 0        0.011224                 9.134124              3.077613e-03
# 1        0.817653                30.530607              1.992932e-07
# 2        0.005095                 8.323161              4.654745e-03
# 3        0.848347                 1.571659              2.124443e-01
# 4        0.033791                62.255387              1.709833e-12
# ...           ...                      ...                       ...
# 8186     0.188699                28.094770              1.057892e-27
# 8187     0.107922                27.831193              1.533460e-27
# 8188     0.336977                19.718678              6.026204e-22
# 8189     0.196434                24.474149              2.199011e-25
# 8190     0.142323                26.292732              2.331561e-27
#
#       Adjusted_R_squared
# 0               0.063981
# 1               0.198818
# 2               0.057972
# 3               0.004781
# 4               0.339826
# ...                  ...
# 8186            0.732065
# 8187            0.730143
# 8188            0.653691
# 8189            0.703012
# 8190            0.734260
#
# [8191 rows x 10 columns]
#
# Feuille : Platinium
#       Unnamed: 0                             Variables_explicatives  \
# 0              0                                     ['RUSSIA GDP']
# 1              1                         ['USA INFLATION RATE CPI']
# 2              2                             ['USA INTEREST RATES']
# 3              3                      ['USA INDUSTRIAL PRODUCTION']
# 4              4                               ['RUSSIA RTS INDEX']
# ...          ...                                                ...
# 8186        8186  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8187        8187  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8188        8188  ['RUSSIA GDP', 'USA INTEREST RATES', 'USA INDU...
# 8189        8189  ['USA INFLATION RATE CPI', 'USA INTEREST RATES...
# 8190        8190  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
#
#                                            Coefficients  \
# 0     const         1031.313749\nRUSSIA GDP    -559....
# 1     const                     865.155563\nUSA INFL...
# 2     const                 970.779081\nUSA INTEREST...
# 3     const                        1031.694346\nUSA ...
# 4     const               922.429200\nRUSSIA RTS IND...
# ...                                                 ...
# 8186  const                     429.506748\nRUSSIA G...
# 8187  const                        413.134932\nRUSSI...
# 8188  const                         302.954504\nRUSS...
# 8189  const                        427.976338\nUSA I...
# 8190  const                        428.578692\nRUSSI...
#
#                                        Erreurs_standard  \
# 0     const          17.388540\nRUSSIA GDP    502.58...
# 1     const                     16.466790\nUSA INFLA...
# 2     const                 22.522487\nUSA INTEREST ...
# 3     const                        17.482088\nUSA IN...
# 4     const               91.410885\nRUSSIA RTS INDE...
# ...                                                 ...
# 8186  const                     115.156243\nRUSSIA G...
# 8187  const                        125.469129\nRUSSI...
# 8188  const                        144.061446\nRUSSI...
# 8189  const                        116.123515\nUSA I...
# 8190  const                        115.578131\nRUSSI...
#
#                                                 P-value  Autocorr_test  \
# 0     const         1.093108e-89\nRUSSIA GDP    2.68...       0.116242
# 1     const                     1.059793e-83\nUSA IN...       0.295056
# 2     const                 4.676429e-74\nUSA INTERE...       0.122846
# 3     const                        1.933900e-89\nUSA...       0.105952
# 4     const               1.219396e-17\nRUSSIA RTS I...       0.111270
# ...                                                 ...            ...
# 8186  const                     3.085091e-04\nRUSSIA...       0.807620
# 8187  const                        1.345193e-03\nRUS...       0.614000
# 8188  const                        3.781486e-02\nRUS...       0.762852
# 8189  const                        3.601078e-04\nUSA...       0.760996
# 8190  const                        3.341600e-04\nRUS...       0.776774
#
#       Hetero_test  Multicollinearity_Fstat  Multicollinearity_pvalue  \
# 0        0.463951                 1.237531              2.682086e-01
# 1        0.020455               183.211056              9.086410e-26
# 2        0.209611                15.654154              1.302711e-04
# 3        0.458678                 0.020474              8.864664e-01
# 4        0.080235                 1.484471              2.255066e-01
# ...           ...                      ...                       ...
# 8186     0.496546                40.324115              3.563629e-34
# 8187     0.053734                32.536265              2.897811e-30
# 8188     0.055391                21.968330              1.233993e-23
# 8189     0.301907                39.519156              8.453691e-34
# 8190     0.515207                36.979699              2.056590e-33
#
#       Adjusted_R_squared
# 0               0.001992
# 1               0.604928
# 2               0.109642
# 3              -0.008300
# 4               0.004055
# ...                  ...
# 8186            0.798609
# 8187            0.760773
# 8188            0.678916
# 8189            0.795262
# 8190            0.797183
#
# [8191 rows x 10 columns]
#
# Feuille : Zinc
#       Unnamed: 0                             Variables_explicatives  \
# 0              0                                     ['RUSSIA GDP']
# 1              1                         ['USA INFLATION RATE CPI']
# 2              2                             ['USA INTEREST RATES']
# 3              3                      ['USA INDUSTRIAL PRODUCTION']
# 4              4                               ['RUSSIA RTS INDEX']
# ...          ...                                                ...
# 8186        8186  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8187        8187  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8188        8188  ['RUSSIA GDP', 'USA INTEREST RATES', 'USA INDU...
# 8189        8189  ['USA INFLATION RATE CPI', 'USA INTEREST RATES...
# 8190        8190  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
#
#                                            Coefficients  \
# 0     const         2570.423278\nRUSSIA GDP    4608....
# 1     const                     2787.289280\nUSA INF...
# 2     const                 2641.756566\nUSA INTERES...
# 3     const                        2566.508532\nUSA ...
# 4     const               2705.305649\nRUSSIA RTS IN...
# ...                                                 ...
# 8186  const                      252.864711\nRUSSIA ...
# 8187  const                         271.180723\nRUSS...
# 8188  const                         645.189784\nRUSS...
# 8189  const                        236.527098\nUSA I...
# 8190  const                         240.380066\nRUSS...
#
#                                        Erreurs_standard  \
# 0     const           50.877304\nRUSSIA GDP    1470....
# 1     const                     74.924126\nUSA INFLA...
# 2     const                 71.907498\nUSA INTEREST ...
# 3     const                        52.963525\nUSA IN...
# 4     const               278.351269\nRUSSIA RTS IND...
# ...                                                 ...
# 8186  const                      461.543412\nRUSSIA ...
# 8187  const                         466.175684\nRUSS...
# 8188  const                         533.159987\nRUSS...
# 8189  const                        466.647261\nUSA I...
# 8190  const                         457.639705\nRUSS...
#
#                                                 P-value  Autocorr_test  \
# 0     const         8.852446e-82\nRUSSIA GDP    2.17...       0.128665
# 1     const                     5.022114e-67\nUSA IN...       0.128743
# 2     const                 1.960660e-66\nUSA INTERE...       0.109300
# 3     const                        9.707451e-80\nUSA...       0.105062
# 4     const               9.298478e-17\nRUSSIA RTS I...       0.105336
# ...                                                 ...            ...
# 8186  const                     5.849239e-01\nRUSSIA...       0.927183
# 8187  const                        5.619832e-01\nRUS...       0.863576
# 8188  const                        0.228898\nRUSSIA ...       0.821466
# 8189  const                        6.132926e-01\nUSA...       0.978745
# 8190  const                        6.004991e-01\nRUS...       0.972218
#
#       Hetero_test  Multicollinearity_Fstat  Multicollinearity_pvalue  \
# 0        0.167838                 9.820049              2.177967e-03
# 1        0.014184                15.522169              1.385500e-04
# 2        0.064039                 2.330219              1.295600e-01
# 3        0.339550                 0.004383              9.473300e-01
# 4        0.697153                 0.257531              6.127684e-01
# ...           ...                      ...                       ...
# 8186     0.151950                19.214176              1.499165e-21
# 8187     0.028748                18.640700              4.304461e-21
# 8188     0.197017                11.776928              8.428276e-15
# 8189     0.209492                18.608979              4.565782e-21
# 8190     0.200829                18.264846              1.757290e-21
#
#       Adjusted_R_squared
# 0               0.069004
# 1               0.108762
# 2               0.011055
# 3              -0.008437
# 4              -0.006278
# ...                  ...
# 8186            0.647481
# 8187            0.640145
# 8188            0.520786
# 8189            0.639730
# 8190            0.653509
#
# [8191 rows x 10 columns]
#
# Feuille : Lead
#       Unnamed: 0                             Variables_explicatives  \
# 0              0                                     ['RUSSIA GDP']
# 1              1                         ['USA INFLATION RATE CPI']
# 2              2                             ['USA INTEREST RATES']
# 3              3                      ['USA INDUSTRIAL PRODUCTION']
# 4              4                               ['RUSSIA RTS INDEX']
# ...          ...                                                ...
# 8186        8186  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8187        8187  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8188        8188  ['RUSSIA GDP', 'USA INTEREST RATES', 'USA INDU...
# 8189        8189  ['USA INFLATION RATE CPI', 'USA INTEREST RATES...
# 8190        8190  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
#
#                                            Coefficients  \
# 0     const         2067.865539\nRUSSIA GDP    1627....
# 1     const                     2039.076584\nUSA INF...
# 2     const                 1989.720419\nUSA INTERES...
# 3     const                        2066.234277\nUSA ...
# 4     const               2104.978318\nRUSSIA RTS IN...
# ...                                                 ...
# 8186  const                     1411.397565\nRUSSIA ...
# 8187  const                        1389.990360\nRUSS...
# 8188  const                        1478.275562\nRUSS...
# 8189  const                        1405.251144\nUSA ...
# 8190  const                        1406.503852\nRUSS...
#
#                                        Erreurs_standard  \
# 0     const          20.277226\nRUSSIA GDP    586.07...
# 1     const                     31.319098\nUSA INFLA...
# 2     const                 26.777164\nUSA INTEREST ...
# 3     const                        20.917696\nUSA IN...
# 4     const               110.077866\nRUSSIA RTS IND...
# ...                                                 ...
# 8186  const                     217.467167\nRUSSIA G...
# 8187  const                        222.001570\nRUSSI...
# 8188  const                        219.347540\nRUSSI...
# 8189  const                        218.014573\nUSA I...
# 8190  const                        216.522163\nRUSSI...
#
#                                                 P-value  Autocorr_test  \
# 0     const         6.528452e-117\nRUSSIA GDP     6....       0.317568
# 1     const                     2.516316e-94\nUSA IN...       0.305909
# 2     const                 6.131380e-101\nUSA INTER...       0.347884
# 3     const                        2.692235e-115\nUS...       0.300271
# 4     const               5.984426e-38\nRUSSIA RTS I...       0.305085
# ...                                                 ...            ...
# 8186  const                     2.745769e-09\nRUSSIA...       1.010655
# 8187  const                        8.105148e-09\nRUS...       1.059182
# 8188  const                        8.308337e-10\nRUS...       0.995012
# 8189  const                        3.392557e-09\nUSA...       1.047805
# 8190  const                        2.743155e-09\nRUS...       1.025257
#
#       Hetero_test  Multicollinearity_Fstat  Multicollinearity_pvalue  \
# 0        0.202659                 7.707909              6.395982e-03
# 1        0.004714                 1.374284              2.434386e-01
# 2        0.661521                17.558406              5.405511e-05
# 3        0.390120                 0.183470              6.691888e-01
# 4        0.691850                 0.126611              7.226071e-01
# ...           ...                      ...                       ...
# 8186     0.339034                10.878218              7.656235e-14
# 8187     0.331874                10.066007              6.063286e-13
# 8188     0.086437                10.182658              4.483914e-13
# 8189     0.707075                10.783797              9.701994e-14
# 8190     0.366911                10.282995              1.065815e-13
#
#       Adjusted_R_squared
# 0               0.053361
# 1               0.003135
# 2               0.122150
# 3              -0.006909
# 4              -0.007394
# ...                  ...
# 8186            0.499029
# 8187            0.477594
# 8188            0.480784
# 8189            0.496628
# 8190            0.503502
#
# [8191 rows x 10 columns]

# %%
# Dictionary to store the best model for each dependent variable
best_models = {}

# Loop over the dependent variables
for dependent_var, results_table in df.items():
    # Find the row with the highest adjusted R-squared
    best_model_row = results_table.loc[results_table['Adjusted_R_squared'].idxmax()]

    # Save the best model to the dictionary
    best_models[dependent_var] = {
        'Variables_explicatives': best_model_row['Variables_explicatives'],
        'Coefficients': best_model_row['Coefficients'],
        'Erreurs_standard': best_model_row['Erreurs_standard'],
        'P-value': best_model_row['P-value'],
        'Autocorr_test': best_model_row['Autocorr_test'],
        'Hetero_test': best_model_row['Hetero_test'],
        'Multicollinearity_Fstat': best_model_row['Multicollinearity_Fstat'],
        'Multicollinearity_pvalue': best_model_row['Multicollinearity_pvalue'],
        'Adjusted_R_squared': best_model_row['Adjusted_R_squared']
    }

# Print the best models for each dependent variable
for dependent_var, best_model in best_models.items():
    print(f"Meilleur modèle pour la variable dépendante : {dependent_var}")
    print(best_model)
    print()
# Out:
# Meilleur modèle pour la variable dépendante : WTI
# {'Variables_explicatives': "['USA INFLATION RATE CPI', 'USA INTEREST RATES', 'USA INDUSTRIAL PRODUCTION', 'RUSSIA RTS INDEX', 'RUSSIA INFLATION RATE', 'RUSSIA TRADE BALANCE', 'USA UNEMPLOYMENT RATE', 'RUSSIA RETAIL SALES', 'USA IMPORT PRICES', 'RUSSIA CSI']", 'Coefficients': 'const                       -87.412886\nUSA INFLATION RATE CPI        4.187682\nUSA INTEREST RATES           -2.501490\nUSA INDUSTRIAL PRODUCTION     1.439646\nRUSSIA RTS INDEX             -0.034872\nRUSSIA INFLATION RATE         1.033221\nRUSSIA TRADE BALANCE          1.699234\nUSA UNEMPLOYMENT RATE         1.524072\nRUSSIA RETAIL SALES          -0.202413\nUSA IMPORT PRICES            -1.782786\nRUSSIA CSI                    1.931766\ndtype: float64', 'Erreurs_standard': 'const                        14.237165\nUSA INFLATION RATE CPI        0.635761\nUSA INTEREST RATES            1.400141\nUSA INDUSTRIAL PRODUCTION     0.717141\nRUSSIA RTS INDEX              0.006607\nRUSSIA INFLATION RATE         0.316716\nRUSSIA TRADE BALANCE          0.291362\nUSA UNEMPLOYMENT RATE         0.772674\nRUSSIA RETAIL SALES           0.101252\nUSA IMPORT PRICES             1.282120\nRUSSIA CSI                    0.213851\ndtype: float64', 'P-value': 'const                        1.369142e-08\nUSA INFLATION RATE CPI       1.639734e-09\nUSA INTEREST RATES           7.678223e-02\nUSA INDUSTRIAL PRODUCTION    4.717294e-02\nRUSSIA RTS INDEX             6.702079e-07\nRUSSIA INFLATION RATE        1.475930e-03\nRUSSIA TRADE BALANCE         5.677834e-08\nUSA UNEMPLOYMENT RATE        5.108915e-02\nRUSSIA RETAIL SALES          4.808591e-02\nUSA IMPORT PRICES            1.672102e-01\nRUSSIA CSI                   6.831633e-15\ndtype: float64', 'Autocorr_test': 0.9285713927646405, 'Hetero_test': 0.2913041672780484, 'Multicollinearity_Fstat': 38.20178879957645, 'Multicollinearity_pvalue': 3.89775140622724e-31, 'Adjusted_R_squared': 0.7576463039142344}
#
# Meilleur modèle pour la variable dépendante : Henry Hub Nat Gas
# {'Variables_explicatives': "['USA INTEREST RATES', 'USA INDUSTRIAL PRODUCTION', 'RUSSIA RTS INDEX', 'RUSSIA TRADE BALANCE', 'RUSSIA RETAIL SALES', 'RUSSIA EXPORT PRICES', 'USA IMPORT PRICES', 'RUSSIA CSI']", 'Coefficients': 'const                       -4.375378\nUSA INTEREST RATES          -0.470955\nUSA INDUSTRIAL PRODUCTION    0.130838\nRUSSIA RTS INDEX            -0.001082\nRUSSIA TRADE BALANCE         0.156713\nRUSSIA RETAIL SALES         -0.022369\nRUSSIA EXPORT PRICES        -0.114133\nUSA IMPORT PRICES           -0.252752\nRUSSIA CSI                   0.097026\ndtype: float64', 'Erreurs_standard': 'const                        1.179667\nUSA INTEREST RATES           0.100750\nUSA INDUSTRIAL PRODUCTION    0.066916\nRUSSIA RTS INDEX             0.000518\nRUSSIA TRADE BALANCE         0.022716\nRUSSIA RETAIL SALES          0.009585\nRUSSIA EXPORT PRICES         0.033561\nUSA IMPORT PRICES            0.116553\nRUSSIA CSI                   0.018329\ndtype: float64', 'P-value': 'const                        3.266680e-04\nUSA INTEREST RATES           8.341154e-06\nUSA INDUSTRIAL PRODUCTION    5.306654e-02\nRUSSIA RTS INDEX             3.915642e-02\nRUSSIA TRADE BALANCE         3.395837e-10\nRUSSIA RETAIL SALES          2.140891e-02\nRUSSIA EXPORT PRICES         9.347380e-04\nUSA IMPORT PRICES            3.224998e-02\nRUSSIA CSI                   6.112631e-07\ndtype: float64', 'Autocorr_test': 0.8072731771879191, 'Hetero_test': 0.005093532916138505, 'Multicollinearity_Fstat': 14.13746447753768, 'Multicollinearity_pvalue': 4.994846822310466e-14, 'Adjusted_R_squared': 0.4689863859737227}
#
# Meilleur modèle pour la variable dépendante : Corn
# {'Variables_explicatives': "['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA INDUSTRIAL PRODUCTION', 'RUSSIA RTS INDEX', 'RUSSIA INFLATION RATE', 'RUSSIA TRADE BALANCE', 'USA UNEMPLOYMENT RATE', 'RUSSIA EXPORT PRICES', 'RUSSIA CSI']", 'Coefficients': 'const                       -643.990370\nRUSSIA GDP                   683.581150\nUSA INFLATION RATE CPI       -25.064411\nUSA INDUSTRIAL PRODUCTION      7.284105\nRUSSIA RTS INDEX              -0.105371\nRUSSIA INFLATION RATE         17.653872\nRUSSIA TRADE BALANCE          10.248583\nUSA UNEMPLOYMENT RATE         25.607909\nRUSSIA EXPORT PRICES          -4.504258\nRUSSIA CSI                    11.608106\ndtype: float64', 'Erreurs_standard': 'const                         95.907752\nRUSSIA GDP                   307.935784\nUSA INFLATION RATE CPI         4.444398\nUSA INDUSTRIAL PRODUCTION      4.314633\nRUSSIA RTS INDEX               0.043790\nRUSSIA INFLATION RATE          2.198189\nRUSSIA TRADE BALANCE           2.053926\nUSA UNEMPLOYMENT RATE          4.972529\nRUSSIA EXPORT PRICES           2.991929\nRUSSIA CSI                     1.243467\ndtype: float64', 'P-value': 'const                        8.599403e-10\nRUSSIA GDP                   2.847787e-02\nUSA INFLATION RATE CPI       1.336518e-07\nUSA INDUSTRIAL PRODUCTION    9.419975e-02\nRUSSIA RTS INDEX             1.778230e-02\nRUSSIA INFLATION RATE        1.169616e-12\nRUSSIA TRADE BALANCE         2.279375e-06\nUSA UNEMPLOYMENT RATE        1.152962e-06\nRUSSIA EXPORT PRICES         1.350695e-01\nRUSSIA CSI                   1.305731e-15\ndtype: float64', 'Autocorr_test': 0.7961266013885971, 'Hetero_test': 0.02069772540905481, 'Multicollinearity_Fstat': 29.80912190088022, 'Multicollinearity_pvalue': 1.180276420159581e-25, 'Adjusted_R_squared': 0.6854199527025201}
#
# Meilleur modèle pour la variable dépendante : Gold
# {'Variables_explicatives': "['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA INTEREST RATES', 'USA INDUSTRIAL PRODUCTION', 'RUSSIA RTS INDEX', 'USA GDP', 'RUSSIA INFLATION RATE', 'RUSSIA TRADE BALANCE', 'USA UNEMPLOYMENT RATE', 'RUSSIA RETAIL SALES', 'USA IMPORT PRICES', 'RUSSIA CSI']", 'Coefficients': 'const                         847.367128\nRUSSIA GDP                   2593.197784\nUSA INFLATION RATE CPI        -56.156630\nUSA INTEREST RATES            -45.089788\nUSA INDUSTRIAL PRODUCTION      20.056656\nRUSSIA RTS INDEX               -0.437925\nUSA GDP                        -7.488251\nRUSSIA INFLATION RATE          34.929151\nRUSSIA TRADE BALANCE            8.500046\nUSA UNEMPLOYMENT RATE          24.320927\nRUSSIA RETAIL SALES            -1.692326\nUSA IMPORT PRICES             -43.861067\nRUSSIA CSI                     10.891957\ndtype: float64', 'Erreurs_standard': 'const                        213.406771\nRUSSIA GDP                   728.041530\nUSA INFLATION RATE CPI         9.581644\nUSA INTEREST RATES            23.976852\nUSA INDUSTRIAL PRODUCTION     10.931529\nRUSSIA RTS INDEX               0.101468\nUSA GDP                        6.283304\nRUSSIA INFLATION RATE          5.498670\nRUSSIA TRADE BALANCE           4.528219\nUSA UNEMPLOYMENT RATE         14.925396\nRUSSIA RETAIL SALES            1.519287\nUSA IMPORT PRICES             19.210719\nRUSSIA CSI                     3.239865\ndtype: float64', 'P-value': 'const                        1.301456e-04\nRUSSIA GDP                   5.511560e-04\nUSA INFLATION RATE CPI       5.164687e-08\nUSA INTEREST RATES           6.275163e-02\nUSA INDUSTRIAL PRODUCTION    6.932046e-02\nRUSSIA RTS INDEX             3.558822e-05\nUSA GDP                      2.359883e-01\nRUSSIA INFLATION RATE        5.278719e-09\nRUSSIA TRADE BALANCE         6.322440e-02\nUSA UNEMPLOYMENT RATE        1.061479e-01\nRUSSIA RETAIL SALES          2.678203e-01\nUSA IMPORT PRICES            2.439726e-02\nRUSSIA CSI                   1.074567e-03\ndtype: float64', 'Autocorr_test': 0.443560584786003, 'Hetero_test': 0.03923076266030711, 'Multicollinearity_Fstat': 19.79186268658841, 'Multicollinearity_pvalue': 5.286535363873176e-22, 'Adjusted_R_squared': 0.6545742018114808}
#
# Meilleur modèle pour la variable dépendante : Sugar 11
# {'Variables_explicatives': "['RUSSIA GDP', 'USA INFLATION RATE CPI', 'RUSSIA RTS INDEX', 'USA GDP', 'RUSSIA INFLATION RATE', 'RUSSIA TRADE BALANCE', 'USA UNEMPLOYMENT RATE', 'RUSSIA EXPORT PRICES', 'USA IMPORT PRICES', 'RUSSIA CSI']", 'Coefficients': 'const                     -7.556908\nRUSSIA GDP                12.439894\nUSA INFLATION RATE CPI    -0.516428\nRUSSIA RTS INDEX           0.003565\nUSA GDP                   -0.155143\nRUSSIA INFLATION RATE      0.324436\nRUSSIA TRADE BALANCE       0.165853\nUSA UNEMPLOYMENT RATE      0.259089\nRUSSIA EXPORT PRICES      -0.242162\nUSA IMPORT PRICES         -1.019556\nRUSSIA CSI                 0.191611\ndtype: float64', 'Erreurs_standard': 'const                      3.127966\nRUSSIA GDP                10.198631\nUSA INFLATION RATE CPI     0.154663\nRUSSIA RTS INDEX           0.001469\nUSA GDP                    0.092538\nRUSSIA INFLATION RATE      0.071905\nRUSSIA TRADE BALANCE       0.068215\nUSA UNEMPLOYMENT RATE      0.163413\nRUSSIA EXPORT PRICES       0.103328\nUSA IMPORT PRICES          0.264721\nRUSSIA CSI                 0.040478\ndtype: float64', 'P-value': 'const                     0.017358\nRUSSIA GDP                0.225188\nUSA INFLATION RATE CPI    0.001151\nRUSSIA RTS INDEX          0.016896\nUSA GDP                   0.096500\nRUSSIA INFLATION RATE     0.000016\nRUSSIA TRADE BALANCE      0.016673\nUSA UNEMPLOYMENT RATE     0.115753\nRUSSIA EXPORT PRICES      0.020910\nUSA IMPORT PRICES         0.000199\nRUSSIA CSI                0.000007\ndtype: float64', 'Autocorr_test': 0.6263151166063767, 'Hetero_test': 0.0747539774981999, 'Multicollinearity_Fstat': 11.92105003327164, 'Multicollinearity_pvalue': 1.133396275696159e-13, 'Adjusted_R_squared': 0.4785516011467238}
#
# Meilleur modèle pour la variable dépendante : Cocoa
# {'Variables_explicatives': "['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA INTEREST RATES', 'RUSSIA RTS INDEX', 'RUSSIA TRADE BALANCE', 'USA UNEMPLOYMENT RATE', 'RUSSIA EXPORT PRICES']", 'Coefficients': 'const                     2253.129587\nRUSSIA GDP               -1858.620072\nUSA INFLATION RATE CPI     103.350708\nUSA INTEREST RATES        -193.665290\nRUSSIA RTS INDEX             0.285143\nRUSSIA TRADE BALANCE       -18.673924\nUSA UNEMPLOYMENT RATE       36.292401\nRUSSIA EXPORT PRICES       -13.949693\ndtype: float64', 'Erreurs_standard': 'const                     153.366069\nRUSSIA GDP                952.938665\nUSA INFLATION RATE CPI     13.772654\nUSA INTEREST RATES         24.892577\nRUSSIA RTS INDEX            0.129793\nRUSSIA TRADE BALANCE        5.772051\nUSA UNEMPLOYMENT RATE      18.533942\nRUSSIA EXPORT PRICES        9.838453\ndtype: float64', 'P-value': 'const                     6.998173e-28\nRUSSIA GDP                5.362605e-02\nUSA INFLATION RATE CPI    1.587754e-11\nUSA INTEREST RATES        3.881024e-12\nRUSSIA RTS INDEX          3.008735e-02\nRUSSIA TRADE BALANCE      1.598132e-03\nUSA UNEMPLOYMENT RATE     5.269820e-02\nRUSSIA EXPORT PRICES      1.590036e-01\ndtype: float64', 'Autocorr_test': 0.9067382143242124, 'Hetero_test': 0.2162220897270113, 'Multicollinearity_Fstat': 27.66257217451046, 'Multicollinearity_pvalue': 9.60128477286137e-22, 'Adjusted_R_squared': 0.6106505147691611}
#
# Meilleur modèle pour la variable dépendante : Live Cattle
# {'Variables_explicatives': "['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA INTEREST RATES', 'USA INDUSTRIAL PRODUCTION', 'RUSSIA RTS INDEX', 'USA GDP', 'RUSSIA INFLATION RATE', 'USA UNEMPLOYMENT RATE', 'USA IMPORT PRICES', 'RUSSIA CSI']", 'Coefficients': 'const                          9.642993\nRUSSIA GDP                   176.207705\nUSA INFLATION RATE CPI         3.837843\nUSA INTEREST RATES            -2.671591\nUSA INDUSTRIAL PRODUCTION      0.910053\nRUSSIA RTS INDEX               0.023139\nUSA GDP                        0.933781\nRUSSIA INFLATION RATE          1.415197\nUSA UNEMPLOYMENT RATE          5.602191\nUSA IMPORT PRICES             -1.970122\nRUSSIA CSI                     0.588883\ndtype: float64', 'Erreurs_standard': 'const                        12.499376\nRUSSIA GDP                   42.568886\nUSA INFLATION RATE CPI        0.575488\nUSA INTEREST RATES            1.424723\nUSA INDUSTRIAL PRODUCTION     0.632294\nRUSSIA RTS INDEX              0.005864\nUSA GDP                       0.375131\nRUSSIA INFLATION RATE         0.312253\nUSA UNEMPLOYMENT RATE         0.881373\nUSA IMPORT PRICES             1.138026\nRUSSIA CSI                    0.182500\ndtype: float64', 'P-value': 'const                        4.420929e-01\nRUSSIA GDP                   6.885905e-05\nUSA INFLATION RATE CPI       1.104062e-09\nUSA INTEREST RATES           6.344641e-02\nUSA INDUSTRIAL PRODUCTION    1.529348e-01\nRUSSIA RTS INDEX             1.409752e-04\nUSA GDP                      1.431385e-02\nRUSSIA INFLATION RATE        1.502890e-05\nUSA UNEMPLOYMENT RATE        4.939042e-09\nUSA IMPORT PRICES            8.625013e-02\nRUSSIA CSI                   1.653609e-03\ndtype: float64', 'Autocorr_test': 0.8561121662060012, 'Hetero_test': 0.1295156874579293, 'Multicollinearity_Fstat': 34.94914741360252, 'Multicollinearity_pvalue': 1.507923062480048e-29, 'Adjusted_R_squared': 0.7404531889622552}
#
# Meilleur modèle pour la variable dépendante : Platinium
# {'Variables_explicatives': "['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA INTEREST RATES', 'RUSSIA RTS INDEX', 'USA GDP', 'RUSSIA INFLATION RATE', 'USA UNEMPLOYMENT RATE']", 'Coefficients': 'const                     405.634425\nRUSSIA GDP                559.803954\nUSA INFLATION RATE CPI     45.490030\nUSA INTEREST RATES         58.129145\nRUSSIA RTS INDEX            0.098345\nUSA GDP                    -5.325809\nRUSSIA INFLATION RATE      24.788472\nUSA UNEMPLOYMENT RATE      29.980092\ndtype: float64', 'Erreurs_standard': 'const                      71.056160\nRUSSIA GDP                360.981143\nUSA INFLATION RATE CPI      4.846023\nUSA INTEREST RATES         10.435779\nRUSSIA RTS INDEX            0.048648\nUSA GDP                     3.185941\nRUSSIA INFLATION RATE       2.649526\nUSA UNEMPLOYMENT RATE       7.172887\ndtype: float64', 'P-value': 'const                     9.470007e-08\nRUSSIA GDP                1.237745e-01\nUSA INFLATION RATE CPI    8.590474e-16\nUSA INTEREST RATES        1.770936e-07\nRUSSIA RTS INDEX          4.560643e-02\nUSA GDP                   9.738321e-02\nRUSSIA INFLATION RATE     1.014224e-15\nUSA UNEMPLOYMENT RATE     5.813429e-05\ndtype: float64', 'Autocorr_test': 0.8087720150719352, 'Hetero_test': 0.2823275888967711, 'Multicollinearity_Fstat': 72.11545353704673, 'Multicollinearity_pvalue': 1.502122767131799e-38, 'Adjusted_R_squared': 0.8070712988743498}
#
# Meilleur modèle pour la variable dépendante : Zinc
# {'Variables_explicatives': "['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA INTEREST RATES', 'USA INDUSTRIAL PRODUCTION', 'RUSSIA RTS INDEX', 'USA GDP', 'RUSSIA TRADE BALANCE', 'USA UNEMPLOYMENT RATE', 'RUSSIA RETAIL SALES', 'USA IMPORT PRICES', 'RUSSIA CSI']", 'Coefficients': 'const                         321.835675\nRUSSIA GDP                   3056.317699\nUSA INFLATION RATE CPI       -139.214577\nUSA INTEREST RATES           -126.488671\nUSA INDUSTRIAL PRODUCTION      40.229384\nRUSSIA RTS INDEX               -0.766330\nUSA GDP                       -14.480470\nRUSSIA TRADE BALANCE           67.735622\nUSA UNEMPLOYMENT RATE         -56.983496\nRUSSIA RETAIL SALES            -5.849826\nUSA IMPORT PRICES             -92.788708\nRUSSIA CSI                     39.664170\ndtype: float64', 'Erreurs_standard': 'const                         407.512100\nRUSSIA GDP                   1328.195969\nUSA INFLATION RATE CPI         17.643052\nUSA INTEREST RATES             45.321584\nUSA INDUSTRIAL PRODUCTION      23.011605\nRUSSIA RTS INDEX                0.200542\nUSA GDP                        13.241646\nRUSSIA TRADE BALANCE            9.027023\nUSA UNEMPLOYMENT RATE          30.509808\nRUSSIA RETAIL SALES             3.205084\nUSA IMPORT PRICES              40.125113\nRUSSIA CSI                      6.832967\ndtype: float64', 'P-value': 'const                        4.314000e-01\nRUSSIA GDP                   2.330551e-02\nUSA INFLATION RATE CPI       2.633996e-12\nUSA INTEREST RATES           6.216000e-03\nUSA INDUSTRIAL PRODUCTION    8.326735e-02\nRUSSIA RTS INDEX             2.221966e-04\nUSA GDP                      2.765833e-01\nRUSSIA TRADE BALANCE         1.858983e-11\nUSA UNEMPLOYMENT RATE        6.451345e-02\nRUSSIA RETAIL SALES          7.073895e-02\nUSA IMPORT PRICES            2.264678e-02\nRUSSIA CSI                   6.543819e-08\ndtype: float64', 'Autocorr_test': 0.9830368463805647, 'Hetero_test': 0.2675079792751264, 'Multicollinearity_Fstat': 21.84382887909705, 'Multicollinearity_pvalue': 1.011076121658684e-22, 'Adjusted_R_squared': 0.6583229687585329}
#
# Meilleur modèle pour la variable dépendante : Lead
# {'Variables_explicatives': "['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA INTEREST RATES', 'USA INDUSTRIAL PRODUCTION', 'RUSSIA RTS INDEX', 'RUSSIA TRADE BALANCE', 'RUSSIA RETAIL SALES', 'USA IMPORT PRICES', 'RUSSIA CSI']", 'Coefficients': 'const                        1511.145157\nRUSSIA GDP                   1251.315740\nUSA INFLATION RATE CPI        -23.356358\nUSA INTEREST RATES             63.547488\nUSA INDUSTRIAL PRODUCTION      17.174747\nRUSSIA RTS INDEX               -0.284599\nRUSSIA TRADE BALANCE           29.507420\nRUSSIA RETAIL SALES            -1.725499\nUSA IMPORT PRICES             -33.566309\nRUSSIA CSI                      6.157096\ndtype: float64', 'Erreurs_standard': 'const                        189.374047\nRUSSIA GDP                   512.095573\nUSA INFLATION RATE CPI         8.099864\nUSA INTEREST RATES            16.479820\nUSA INDUSTRIAL PRODUCTION     10.623438\nRUSSIA RTS INDEX               0.088154\nRUSSIA TRADE BALANCE           4.046647\nRUSSIA RETAIL SALES            1.505062\nUSA IMPORT PRICES             18.874225\nRUSSIA CSI                     2.928265\ndtype: float64', 'P-value': 'const                        1.522906e-12\nRUSSIA GDP                   1.613478e-02\nUSA INFLATION RATE CPI       4.731110e-03\nUSA INTEREST RATES           1.944410e-04\nUSA INDUSTRIAL PRODUCTION    1.088108e-01\nRUSSIA RTS INDEX             1.640936e-03\nRUSSIA TRADE BALANCE         4.981297e-11\nRUSSIA RETAIL SALES          2.540911e-01\nUSA IMPORT PRICES            7.809749e-02\nRUSSIA CSI                   3.777824e-02\ndtype: float64', 'Autocorr_test': 1.055106676633808, 'Hetero_test': 0.2672435132939991, 'Multicollinearity_Fstat': 15.07001013121226, 'Multicollinearity_pvalue': 1.039822664437177e-15, 'Adjusted_R_squared': 0.5155316702937889}

# %%
import pandas as pd

# Charger le fichier Excel dans un DataFrame
df = pd.read_excel('regression_results.xlsx', sheet_name=None)

# Loop through the results dictionary
for dependent_var, results_table in df.items():
    # Find the row with the highest R-squared value
    best_model_row = results_table.loc[results_table['Adjusted_R_squared'].idxmax()]

    # Extract the variables and R-squared value
    best_explanatory_vars = best_model_row['Variables_explicatives']
    best_adj_r_squared = best_model_row['Adjusted_R_squared']

    # Get the index (line number) of the best model row
    line_number = best_model_row.name + 1  # Adding 1 to convert from zero-based index to line number

    # Print the results
    print(f"Variable dépendante : {dependent_var}")
    print(f"Ligne : {line_number}")
    print(f"Variables explicatives : {best_explanatory_vars}")
    print(f"R² ajusté : {best_adj_r_squared}")
    print()
# Out:
# Variable dépendante : WTI
# Ligne : 8057
# Variables explicatives : ['USA INFLATION RATE CPI', 'USA INTEREST RATES', 'USA INDUSTRIAL PRODUCTION', 'RUSSIA RTS INDEX', 'RUSSIA INFLATION RATE', 'RUSSIA TRADE BALANCE', 'USA UNEMPLOYMENT RATE', 'RUSSIA RETAIL SALES', 'USA IMPORT PRICES', 'RUSSIA CSI']
# R² ajusté : 0.7576463039142344
#
# Variable dépendante : Henry Hub Nat Gas
# Ligne : 6988
# Variables explicatives : ['USA INTEREST RATES', 'USA INDUSTRIAL PRODUCTION', 'RUSSIA RTS INDEX', 'RUSSIA TRADE BALANCE', 'RUSSIA RETAIL SALES', 'RUSSIA EXPORT PRICES', 'USA IMPORT PRICES', 'RUSSIA CSI']
# R² ajusté : 0.4689863859737227
#
# Variable dépendante : Corn
# Ligne : 7348
# Variables explicatives : ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA INDUSTRIAL PRODUCTION', 'RUSSIA RTS INDEX', 'RUSSIA INFLATION RATE', 'RUSSIA TRADE BALANCE', 'USA UNEMPLOYMENT RATE', 'RUSSIA EXPORT PRICES', 'RUSSIA CSI']
# R² ajusté : 0.6854199527025201
#
# Variable dépendante : Gold
# Ligne : 8180
# Variables explicatives : ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA INTEREST RATES', 'USA INDUSTRIAL PRODUCTION', 'RUSSIA RTS INDEX', 'USA GDP', 'RUSSIA INFLATION RATE', 'RUSSIA TRADE BALANCE', 'USA UNEMPLOYMENT RATE', 'RUSSIA RETAIL SALES', 'USA IMPORT PRICES', 'RUSSIA CSI']
# R² ajusté : 0.6545742018114808
#
# Variable dépendante : Sugar 11
# Ligne : 7973
# Variables explicatives : ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'RUSSIA RTS INDEX', 'USA GDP', 'RUSSIA INFLATION RATE', 'RUSSIA TRADE BALANCE', 'USA UNEMPLOYMENT RATE', 'RUSSIA EXPORT PRICES', 'USA IMPORT PRICES', 'RUSSIA CSI']
# R² ajusté : 0.4785516011467238
#
# Variable dépendante : Cocoa
# Ligne : 4217
# Variables explicatives : ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA INTEREST RATES', 'RUSSIA RTS INDEX', 'RUSSIA TRADE BALANCE', 'USA UNEMPLOYMENT RATE', 'RUSSIA EXPORT PRICES']
# R² ajusté : 0.6106505147691611
#
# Variable dépendante : Live Cattle
# Ligne : 7829
# Variables explicatives : ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA INTEREST RATES', 'USA INDUSTRIAL PRODUCTION', 'RUSSIA RTS INDEX', 'USA GDP', 'RUSSIA INFLATION RATE', 'USA UNEMPLOYMENT RATE', 'USA IMPORT PRICES', 'RUSSIA CSI']
# R² ajusté : 0.7404531889622552
#
# Variable dépendante : Platinium
# Ligne : 4181
# Variables explicatives : ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA INTEREST RATES', 'RUSSIA RTS INDEX', 'USA GDP', 'RUSSIA INFLATION RATE', 'USA UNEMPLOYMENT RATE']
# R² ajusté : 0.8070712988743498
#
# Variable dépendante : Zinc
# Ligne : 8117
# Variables explicatives : ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA INTEREST RATES', 'USA INDUSTRIAL PRODUCTION', 'RUSSIA RTS INDEX', 'USA GDP', 'RUSSIA TRADE BALANCE', 'USA UNEMPLOYMENT RATE', 'RUSSIA RETAIL SALES', 'USA IMPORT PRICES', 'RUSSIA CSI']
# R² ajusté : 0.6583229687585329
#
# Variable dépendante : Lead
# Ligne : 7162
# Variables explicatives : ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA INTEREST RATES', 'USA INDUSTRIAL PRODUCTION', 'RUSSIA RTS INDEX', 'RUSSIA TRADE BALANCE', 'RUSSIA RETAIL SALES', 'USA IMPORT PRICES', 'RUSSIA CSI']
# R² ajusté : 0.5155316702937889

# %%
# Dictionary to store the presence of heteroscedasticity, multicollinearity, and serial autocorrelation for each best model
diagnostics_dict = {}

# Loop over the dependent variables and their best models
for dependent_var, best_model in best_models.items():
    # Get the necessary results from the best model
    hetero_test = best_model['Hetero_test']
    multicollinearity_pvalue = best_model['Multicollinearity_pvalue']
    autocorr_test = best_model['Autocorr_test']

    # Determine the presence of heteroscedasticity
    hetero_present = hetero_test < 0.05  # Check if the p-value is below the significance level (e.g., 0.05)

    # Determine the presence of multicollinearity
    multicollinear_present = multicollinearity_pvalue < 0.05

    # Determine the presence of serial autocorrelation
    autocorr_present = autocorr_test < 2 or autocorr_test > 4  # Check if the Durbin-Watson statistic is significantly different from 2

    # Save the diagnostic results to the diagnostics dictionary
    diagnostics_dict[dependent_var] = {
        'Heteroscedasticity': hetero_present,
        'Multicollinearity': multicollinear_present,
        'Serial_Autocorrelation': autocorr_present
    }

# Print the diagnostic results for each dependent variable
for dependent_var, diagnostics in diagnostics_dict.items():
    print(f"Diagnostics for the dependent variable: {dependent_var}")
    print("Heteroscedasticity:", diagnostics['Heteroscedasticity'])
    print("Multicollinearity:", diagnostics['Multicollinearity'])
    print("Serial Autocorrelation:", diagnostics['Serial_Autocorrelation'])
    print()
# Out:
# Diagnostics for the dependent variable: WTI
# Heteroscedasticity: False
# Multicollinearity: True
# Serial Autocorrelation: True
#
# Diagnostics for the dependent variable: Henry Hub Nat Gas
# Heteroscedasticity: True
# Multicollinearity: True
# Serial Autocorrelation: True
#
# Diagnostics for the dependent variable: Corn
# Heteroscedasticity: True
# Multicollinearity: True
# Serial Autocorrelation: True
#
# Diagnostics for the dependent variable: Gold
# Heteroscedasticity: True
# Multicollinearity: True
# Serial Autocorrelation: True
#
# Diagnostics for the dependent variable: Sugar 11
# Heteroscedasticity: False
# Multicollinearity: True
# Serial Autocorrelation: True
#
# Diagnostics for the dependent variable: Cocoa
# Heteroscedasticity: False
# Multicollinearity: True
# Serial Autocorrelation: True
#
# Diagnostics for the dependent variable: Live Cattle
# Heteroscedasticity: False
# Multicollinearity: True
# Serial Autocorrelation: True
#
# Diagnostics for the dependent variable: Platinium
# Heteroscedasticity: False
# Multicollinearity: True
# Serial Autocorrelation: True
#
# Diagnostics for the dependent variable: Zinc
# Heteroscedasticity: False
# Multicollinearity: True
# Serial Autocorrelation: True
#
# Diagnostics for the dependent variable: Lead
# Heteroscedasticity: False
# Multicollinearity: True
# Serial Autocorrelation: True

# %%
# Create a DataFrame from the diagnostics dictionary
diagnostics_df = pd.DataFrame.from_dict(diagnostics_dict, orient='index')

# Count the number of True and False values for each test
count_df = diagnostics_df.apply(pd.value_counts)

# Print the count table
print("Summary of Diagnostic Tests:")
print(count_df)

#if the value for the heteroscedasticity test is True, it means that there is presence of heteroscedasticity in the model
# For the multicollinearity test, if the value is True, it means that there is presence of multicollinearity in the model
#For the serial autocorrelation test, if the value is True, it means that there is serial autocorrelation in the model
# Out:
# Summary of Diagnostic Tests:
#        Heteroscedasticity  Multicollinearity  Serial_Autocorrelation
# False                   7                NaN                     NaN
# True                    3               10.0                    10.0

# %%
#From here is about SQL export procedure
import sqlite3
connection = sqlite3.connect('C:\\Users\\User\\Desktop\\AQM My SQLite Database AssetPr. and Macr.Var - Αντιγραφή.db')
cursor = connection.cursor()

# %%
#SQLITE Datatypes

#NUMERIC
#INTEGER
#REAL
#TEXT
#BLOBS (Binary Large Objects)
#NULL

# %%
cursor.execute("DROP TABLE IF EXISTS Results_1")
cursor.execute("CREATE TABLE RESULTS_1(Dependent_Variable TEXT, Line INTEGER, Explanatory_Variables TEXT, Adjusted_R_Squared REAL)")

# %%
connection.commit()

# %%
# Define your records
records = [
    ('WTI', 8057, 'USA INFLATION RATE CPI;USA INTEREST RATES;USA INDUSTRIAL PRODUCTION;RUSSIA RTS INDEX;RUSSIA INFLATION RATE;RUSSIA TRADE BALANCE;USA UNEMPLOYMENT RATE;RUSSIA RETAIL SALES;USA IMPORT PRICES;RUSSIA CSI', 0.7576463039142344),
    ('Henry Hub Nat Gas', 6988, ';'.join(['USA INTEREST RATES', 'USA INDUSTRIAL PRODUCTION', 'RUSSIA RTS INDEX', 'RUSSIA TRADE BALANCE', 'RUSSIA RETAIL SALES', 'RUSSIA EXPORT PRICES', 'USA IMPORT PRICES', 'RUSSIA CSI']), 0.4689863859737227),
    ('Corn', 7348, ';'.join(['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA INDUSTRIAL PRODUCTION', 'RUSSIA RTS INDEX', 'RUSSIA INFLATION RATE', 'RUSSIA TRADE BALANCE', 'USA UNEMPLOYMENT RATE', 'RUSSIA EXPORT PRICES', 'RUSSIA CSI']), 0.6854199527025201),
    ('Gold', 8180, ';'.join(['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA INTEREST RATES', 'USA INDUSTRIAL PRODUCTION', 'RUSSIA RTS INDEX', 'USA GDP', 'RUSSIA INFLATION RATE', 'RUSSIA TRADE BALANCE', 'USA UNEMPLOYMENT RATE', 'RUSSIA RETAIL SALES', 'USA IMPORT PRICES', 'RUSSIA CSI']), 0.6545742018114808),
    ('Sugar 11', 7973, ';'.join(['RUSSIA GDP', 'USA INFLATION RATE CPI', 'RUSSIA RTS INDEX', 'USA GDP', 'RUSSIA INFLATION RATE', 'RUSSIA TRADE BALANCE', 'USA UNEMPLOYMENT RATE', 'RUSSIA EXPORT PRICES', 'USA IMPORT PRICES', 'RUSSIA CSI']), 0.4785516011467238),
    ('Cocoa', 4217, ';'.join(['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA INTEREST RATES', 'RUSSIA RTS INDEX', 'RUSSIA TRADE BALANCE', 'USA UNEMPLOYMENT RATE', 'RUSSIA EXPORT PRICES']), 0.6106505147691611),
    ('Live Cattle', 7829, ';'.join(['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA INTEREST RATES', 'USA INDUSTRIAL PRODUCTION', 'RUSSIA RTS INDEX', 'USA GDP', 'RUSSIA INFLATION RATE', 'USA UNEMPLOYMENT RATE', 'USA IMPORT PRICES', 'RUSSIA CSI']), 0.7404531889622552),
    ('Platinium', 4181, ';'.join(['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA INTEREST RATES', 'RUSSIA RTS INDEX', 'USA GDP', 'RUSSIA INFLATION RATE', 'USA UNEMPLOYMENT RATE']), 0.8070712988743498),
    ('Zinc', 8117, ';'.join(['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA INTEREST RATES', 'USA INDUSTRIAL PRODUCTION', 'RUSSIA RTS INDEX', 'USA GDP', 'RUSSIA TRADE BALANCE', 'USA UNEMPLOYMENT RATE', 'RUSSIA RETAIL SALES', 'USA IMPORT PRICES', 'RUSSIA CSI']), 0.6583229687585329),
    ('Lead', 7162, ';'.join(['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA INTEREST RATES', 'USA INDUSTRIAL PRODUCTION', 'RUSSIA RTS INDEX', 'RUSSIA TRADE BALANCE', 'RUSSIA RETAIL SALES', 'USA IMPORT PRICES', 'RUSSIA CSI']), 0.5155316702937889)
]


# Prepare SQL query
sql_query = "INSERT INTO Results_1 VALUES (?, ?, ?, ?)"


# Execute the SQL command
cursor.executemany(sql_query, records)

# Commit your changes
connection.commit()

# %%
# Prepare SQL query to fetch all data from the table
sql_query = "SELECT * FROM Results_1"

# Execute the SQL command
cursor.execute(sql_query)

# Fetch all the rows in a list of lists
results = cursor.fetchall()

for row in results:
    print(row)
# Out:
# ('WTI', 8057, 'USA INFLATION RATE CPI;USA INTEREST RATES;USA INDUSTRIAL PRODUCTION;RUSSIA RTS INDEX;RUSSIA INFLATION RATE;RUSSIA TRADE BALANCE;USA UNEMPLOYMENT RATE;RUSSIA RETAIL SALES;USA IMPORT PRICES;RUSSIA CSI', 0.7576463039142344)
# ('Henry Hub Nat Gas', 6988, 'USA INTEREST RATES;USA INDUSTRIAL PRODUCTION;RUSSIA RTS INDEX;RUSSIA TRADE BALANCE;RUSSIA RETAIL SALES;RUSSIA EXPORT PRICES;USA IMPORT PRICES;RUSSIA CSI', 0.4689863859737227)
# ('Corn', 7348, 'RUSSIA GDP;USA INFLATION RATE CPI;USA INDUSTRIAL PRODUCTION;RUSSIA RTS INDEX;RUSSIA INFLATION RATE;RUSSIA TRADE BALANCE;USA UNEMPLOYMENT RATE;RUSSIA EXPORT PRICES;RUSSIA CSI', 0.6854199527025201)
# ('Gold', 8180, 'RUSSIA GDP;USA INFLATION RATE CPI;USA INTEREST RATES;USA INDUSTRIAL PRODUCTION;RUSSIA RTS INDEX;USA GDP;RUSSIA INFLATION RATE;RUSSIA TRADE BALANCE;USA UNEMPLOYMENT RATE;RUSSIA RETAIL SALES;USA IMPORT PRICES;RUSSIA CSI', 0.6545742018114808)
# ('Sugar 11', 7973, 'RUSSIA GDP;USA INFLATION RATE CPI;RUSSIA RTS INDEX;USA GDP;RUSSIA INFLATION RATE;RUSSIA TRADE BALANCE;USA UNEMPLOYMENT RATE;RUSSIA EXPORT PRICES;USA IMPORT PRICES;RUSSIA CSI', 0.4785516011467238)
# ('Cocoa', 4217, 'RUSSIA GDP;USA INFLATION RATE CPI;USA INTEREST RATES;RUSSIA RTS INDEX;RUSSIA TRADE BALANCE;USA UNEMPLOYMENT RATE;RUSSIA EXPORT PRICES', 0.6106505147691611)
# ('Live Cattle', 7829, 'RUSSIA GDP;USA INFLATION RATE CPI;USA INTEREST RATES;USA INDUSTRIAL PRODUCTION;RUSSIA RTS INDEX;USA GDP;RUSSIA INFLATION RATE;USA UNEMPLOYMENT RATE;USA IMPORT PRICES;RUSSIA CSI', 0.7404531889622552)
# ('Platinium', 4181, 'RUSSIA GDP;USA INFLATION RATE CPI;USA INTEREST RATES;RUSSIA RTS INDEX;USA GDP;RUSSIA INFLATION RATE;USA UNEMPLOYMENT RATE', 0.8070712988743498)
# ('Zinc', 8117, 'RUSSIA GDP;USA INFLATION RATE CPI;USA INTEREST RATES;USA INDUSTRIAL PRODUCTION;RUSSIA RTS INDEX;USA GDP;RUSSIA TRADE BALANCE;USA UNEMPLOYMENT RATE;RUSSIA RETAIL SALES;USA IMPORT PRICES;RUSSIA CSI', 0.6583229687585329)
# ('Lead', 7162, 'RUSSIA GDP;USA INFLATION RATE CPI;USA INTEREST RATES;USA INDUSTRIAL PRODUCTION;RUSSIA RTS INDEX;RUSSIA TRADE BALANCE;RUSSIA RETAIL SALES;USA IMPORT PRICES;RUSSIA CSI', 0.5155316702937889)

# %%
import sqlite3
connection = sqlite3.connect('C:\\Users\\User\\Desktop\\AQM My SQLite Database AssetPr. and Macr.Var - Αντιγραφή.db')
cursor = connection.cursor()

# %%
#SQLITE Datatypes

#NUMERIC
#INTEGER
#REAL
#TEXT
#BLOBS (Binary Large Objects)
#NULL

# %%
connection.commit()

# %%
# Boolean values (True/False) are usually stored as integers, where True is represented by 1 and False is represented by 0. However we want to depict the true or falseso we save it like a text(a text string.)
cursor.execute("DROP TABLE IF EXISTS Results_2")
cursor.execute("CREATE TABLE RESULTS_2 (Dependent_Variable TEXT, Heteroscedasticity TEXT, Multicollinearity TEXT, Serial_Autocorrelation TEXT)")

# %%
# Define your records
diagnostics = [
    ('WTI', 'False', 'True', 'True'),
    ('Henry Hub Nat Gas', 'True', 'True', 'True'),
    ('Corn', 'True', 'True', 'True'),
    ('Gold', 'True', 'True', 'True'),
    ('Sugar 11', 'False', 'True', 'True'),
    ('Cocoa', 'False', 'True', 'True'),
    ('Live Cattle', 'False', 'True', 'True'),
    ('Platinium', 'False', 'True', 'True'),
    ('Zinc', 'False', 'True', 'True'),
    ('Lead', 'False', 'True', 'True')
]

# Prepare SQL query
sql_query = "INSERT INTO Results_2 VALUES (?, ?, ?, ?)"

# Execute the SQL command
cursor.executemany(sql_query, diagnostics)

# Commit your changes
connection.commit()

# %%
# Prepare SQL query to fetch all data from the table
sql_query = "SELECT * FROM Results_2"

# Execute the SQL command
cursor.execute(sql_query)

# Fetch all the rows in a list of lists
results = cursor.fetchall()

for row in results:
    print(row)
# Out:
# ('WTI', 'False', 'True', 'True')
# ('Henry Hub Nat Gas', 'True', 'True', 'True')
# ('Corn', 'True', 'True', 'True')
# ('Gold', 'True', 'True', 'True')
# ('Sugar 11', 'False', 'True', 'True')
# ('Cocoa', 'False', 'True', 'True')
# ('Live Cattle', 'False', 'True', 'True')
# ('Platinium', 'False', 'True', 'True')
# ('Zinc', 'False', 'True', 'True')
# ('Lead', 'False', 'True', 'True')

# %%
import sqlite3
connection = sqlite3.connect('C:\\Users\\User\\Desktop\\AQM My SQLite Database AssetPr. and Macr.Var - Αντιγραφή.db')
cursor = connection.cursor()

# %%
#SQLITE Datatypes

#NUMERIC
#INTEGER
#REAL
#TEXT
#BLOBS (Binary Large Objects)
#NULL

# %%
# Boolean values (True/False) are usually stored as integers, where True is represented by 1 and False is represented by 0. However we want to depict the true or false so we save it like a textcursor.execute("DROP TABLE IF EXISTS Results_3")
cursor.execute("DROP TABLE IF EXISTS Results_3")
cursor.execute("""
CREATE TABLE RESULTS_3(
    TestCondition TEXT,
    Heteroscedasticity INTEGER,
    Multicollinearity INTEGER,
    Serial_Autocorrelation INTEGER
);
""")

# %%
# Define your records
records = [
    ('False', 7, None, None),
    ('True', 3, 10, 10),
]

# Prepare SQL query
sql_query = """
INSERT INTO Results_3 (TestCondition, Heteroscedasticity, Multicollinearity, Serial_Autocorrelation) 
VALUES (?, ?, ?, ?)
"""

# Execute the SQL command
cursor.executemany(sql_query, records)

# Commit your changes
connection.commit()

# %%
# Prepare SQL query to fetch all data from the table
sql_query = "SELECT * FROM Results_3"

# Execute the SQL command
cursor.execute(sql_query)

# Fetch all the rows in a list of lists
results = cursor.fetchall()

for row in results:
    print(row)
# Out:
# ('False', 7, None, None)
# ('True', 3, 10, 10)

# %%
# From here is the procedure where it read them from SQL to connect them with python
import sqlite3
import pandas as pd

# Connect to the SQLite database
conn = sqlite3.connect(r'C:\Users\User\Desktop\Results_4.db')

# Get a list of all the table names in the database
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

# tables is a list of tuples, where each tuple has one item (the table name).
# We will flatten this to a simple list of table names.
tables = [table[0] for table in tables]

# Load each table into a DataFrame and store them all in a dictionary
dataframes = {}
for table in tables:
    query = f'SELECT * FROM "{table}"'
    dataframes[table] = pd.read_sql_query(query, conn)

cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('Cocoa',), ('Corn',), ('Henry Hub Nat Gas',), ('Gold',), ('Lead',), ('Live_Cattle',), ('Platinium',), ('Sugar_11',), ('WTI',), ('Zinc',)]

# %%
import sqlite3
import pandas as pd

# Connect to the SQLite database
conn = sqlite3.connect(r'C:\Users\User\Desktop\Results_4.db')

# List of table names
table_names = ['Cocoa', 'Corn', 'Henry Hub Nat Gas', 'Gold', 'Lead', 'Live_Cattle', 'Platinium', 'Sugar_11', 'WTI', 'Zinc']

dataframes = {} # We will store each dataframe in this dictionary, with table names as keys

for table_name in table_names:
    # Create a query to select all from your table
    query = f'SELECT * FROM "{table_name}"'
    
    # Execute the query and load the data into a DataFrame
    data = pd.read_sql_query(query, conn)

    # Now 'data' is a pandas DataFrame containing all data from your table
    dataframes[table_name] = data

# Don't forget to close the connection when you're done:
conn.close()

for table_name, dataframe in dataframes.items():
    print(f"Data for {table_name}:")
    print(dataframe)
    print("\n")  # print a newline for readability
# Out:
# Data for Cocoa:
#       Line                             Variables_explicatives  \
# 0        0                                     ['RUSSIA GDP']
# 1        1                         ['USA INFLATION RATE CPI']
# 2        2                             ['USA INTEREST RATES']
# 3        3                      ['USA INDUSTRIAL PRODUCTION']
# 4        4                               ['RUSSIA RTS INDEX']
# ...    ...                                                ...
# 8186  8186  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8187  8187  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8188  8188  ['RUSSIA GDP', 'USA INTEREST RATES', 'USA INDU...
# 8189  8189  ['USA INFLATION RATE CPI', 'USA INTEREST RATES...
# 8190  8190  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
#
#                                            Coefficients  \
# 0     const         2569.737703\nRUSSIA GDP   -1631....
# 1     const                     2438.557935\nUSA INF...
# 2     const                 2713.313832\nUSA INTERES...
# 3     const                        2571.154517\nUSA ...
# 4     const               2080.702947\nRUSSIA RTS IN...
# ...                                                 ...
# 8186  const                     2381.509851\nRUSSIA ...
# 8187  const                        2433.524341\nRUSS...
# 8188  const                        2083.519163\nRUSS...
# 8189  const                        2383.532458\nUSA ...
# 8190  const                        2381.316076\nRUSS...
#
#                                        Erreurs_standard  \
# 0     const          33.609681\nRUSSIA GDP    971.41...
# 1     const                     48.516482\nUSA INFLA...
# 2     const                 42.533469\nUSA INTEREST ...
# 3     const                        34.016219\nUSA IN...
# 4     const               172.960536\nRUSSIA RTS IND...
# ...                                                 ...
# 8186  const                      317.041277\nRUSSIA ...
# 8187  const                         359.525014\nRUSS...
# 8188  const                         377.242350\nRUSS...
# 8189  const                        322.400626\nUSA I...
# 8190  const                         318.572537\nRUSS...
#
#                                                 P-value Autocorr_test  \
# 0     const         2.260696e-102\nRUSSIA GDP     9....   0,280443927
# 1     const                     1.582634e-81\nUSA IN...   0,311495671
# 2     const                 2.612365e-93\nUSA INTERE...   0,326743867
# 3     const                        8.520853e-102\nUS...   0,276553836
# 4     const               3.038653e-22\nRUSSIA RTS I...   0,317482986
# ...                                                 ...           ...
# 8186  const                     1.859354e-11\nRUSSIA...   0,897844151
# 8187  const                        7.211303e-10\nRUS...   0,883402933
# 8188  const                        2.357178e-07\nRUS...   0,791339865
# 8189  const                        3.360202e-11\nUSA...   0,907923755
# 8190  const                        2.325965e-11\nRUS...    0,89674816
#
#       Hetero_test Multicollinearity_Fstat Multicollinearity_pvalue  \
# 0     0,004774855             2,819229592              0,095787251
# 1     0,131945872             13,35174096              0,000386593
# 2      0,19369411             23,86627158              3,28041E-06
# 3     0,980587568              0,00421229              0,948361731
# 4     0,325005999             8,339414839              0,004616049
# ...           ...                     ...                      ...
# 8186  0,472013457             15,67533707              1,42514E-18
# 8187  0,368346625             10,19490502              4,34448E-13
# 8188  0,242701502             8,133468808              1,13881E-10
# 8189  0,277727821             14,87039994              7,69402E-18
# 8190  0,491167395             14,33461435              5,80538E-18
#
#      Adjusted_R_squared
# 0           0,015057451
# 1           0,094035609
# 2           0,161181874
# 3          -0,008438578
# 4           0,058092835
# ...                 ...
# 8186        0,596752393
# 8187        0,481117156
# 8188        0,418381943
# 8189        0,583106785
# 8190        0,592953633
#
# [8191 rows x 10 columns]
#
#
# Data for Corn:
#       Line                             Variables_explicatives  \
# 0        0                                     ['RUSSIA GDP']
# 1        1                         ['USA INFLATION RATE CPI']
# 2        2                             ['USA INTEREST RATES']
# 3        3                      ['USA INDUSTRIAL PRODUCTION']
# 4        4                               ['RUSSIA RTS INDEX']
# ...    ...                                                ...
# 8186  8186  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8187  8187  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8188  8188  ['RUSSIA GDP', 'USA INTEREST RATES', 'USA INDU...
# 8189  8189  ['USA INFLATION RATE CPI', 'USA INTEREST RATES...
# 8190  8190  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
#
#                                            Coefficients  \
# 0     const         446.487326\nRUSSIA GDP   -482.53...
# 1     const                     464.034008\nUSA INFL...
# 2     const                 466.054025\nUSA INTEREST...
# 3     const                        446.827072\nUSA I...
# 4     const               484.312088\nRUSSIA RTS IND...
# ...                                                 ...
# 8186  const                    -659.170895\nRUSSIA G...
# 8187  const                       -659.685889\nRUSSI...
# 8188  const                       -600.348460\nRUSSI...
# 8189  const                       -662.840434\nUSA I...
# 8190  const                       -662.258261\nRUSSI...
#
#                                        Erreurs_standard  \
# 0     const          11.639619\nRUSSIA GDP    336.41...
# 1     const                     17.544596\nUSA INFLA...
# 2     const                 15.892416\nUSA INTEREST ...
# 3     const                        11.742233\nUSA IN...
# 4     const               61.684258\nRUSSIA RTS INDE...
# ...                                                 ...
# 8186  const                      98.552563\nRUSSIA G...
# 8187  const                         97.130155\nRUSSI...
# 8188  const                        105.281893\nRUSSI...
# 8189  const                        98.016907\nUSA IN...
# 8190  const                         97.267850\nRUSSI...
#
#                                                 P-value Autocorr_test  \
# 0     const         1.775310e-68\nRUSSIA GDP    1.54...    0,10921596
# 1     const                     2.001282e-51\nUSA IN...   0,110209589
# 2     const                 5.056499e-56\nUSA INTERE...   0,113492453
# 3     const                        4.262141e-68\nUSA...   0,109926185
# 4     const               2.094711e-12\nRUSSIA RTS I...   0,111295988
# ...                                                 ...           ...
# 8186  const                     1.062003e-09\nRUSSIA...   0,838304943
# 8187  const                        6.449987e-10\nRUS...   0,782745337
# 8188  const                        1.058901e-07\nRUS...   0,755213554
# 8189  const                        7.431143e-10\nUSA...   0,774450965
# 8190  const                        6.128655e-10\nRUS...   0,791823682
#
#       Hetero_test Multicollinearity_Fstat Multicollinearity_pvalue  \
# 0     0,938800848             2,057277613               0,15412544
# 1     0,017499036             1,709576117              0,193582217
# 2     0,307051116             3,105003152              0,080641602
# 3     0,578676234             0,023747678              0,877791921
# 4     0,493287689             0,381924188              0,537766189
# ...           ...                     ...                      ...
# 8186  0,006594483             21,41462231              3,13273E-23
# 8187  0,083150961             22,29001895              7,23413E-24
# 8188  0,006359438             17,17263922              7,05201E-20
# 8189  0,007416593             21,75460836              1,76468E-23
# 8190  0,012855869             20,59622621              2,40396E-23
#
#      Adjusted_R_squared
# 0           0,008806443
# 1            0,00592748
# 2           0,017381637
# 3           -0,00827166
# 4          -0,005221032
# ...                 ...
# 8186        0,673054888
# 8187        0,682226213
# 8188        0,619895343
# 8189        0,676679021
# 8190        0,681606153
#
# [8191 rows x 10 columns]
#
#
# Data for Henry Hub Nat Gas:
#       Line                             Variables_explicatives  \
# 0        0                                     ['RUSSIA GDP']
# 1        1                         ['USA INFLATION RATE CPI']
# 2        2                             ['USA INTEREST RATES']
# 3        3                      ['USA INDUSTRIAL PRODUCTION']
# 4        4                               ['RUSSIA RTS INDEX']
# ...    ...                                                ...
# 8186  8186  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8187  8187  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8188  8188  ['RUSSIA GDP', 'USA INTEREST RATES', 'USA INDU...
# 8189  8189  ['USA INFLATION RATE CPI', 'USA INTEREST RATES...
# 8190  8190  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
#
#                                            Coefficients  \
# 0     const         3.382679\nRUSSIA GDP    3.520054...
# 1     const                     3.086589\nUSA INFLAT...
# 2     const                 3.429380\nUSA INTEREST R...
# 3     const                        3.378399\nUSA IND...
# 4     const               2.231716\nRUSSIA RTS INDEX...
# ...                                                 ...
# 8186  const                    -4.971324\nRUSSIA GDP...
# 8187  const                       -4.905386\nRUSSIA ...
# 8188  const                       -4.809665\nRUSSIA ...
# 8189  const                       -5.014437\nUSA INF...
# 8190  const                       -5.013137\nRUSSIA ...
#
#                                        Erreurs_standard  \
# 0     const         0.126160\nRUSSIA GDP    3.646409...
# 1     const                     0.187186\nUSA INFLAT...
# 2     const                 0.173560\nUSA INTEREST R...
# 3     const                        0.126627\nUSA IND...
# 4     const               0.657773\nRUSSIA RTS INDEX...
# ...                                                 ...
# 8186  const                     1.389972\nRUSSIA GDP...
# 8187  const                        1.410940\nRUSSIA ...
# 8188  const                        1.362069\nRUSSIA ...
# 8189  const                        1.367789\nUSA INF...
# 8190  const                        1.373804\nRUSSIA ...
#
#                                                 P-value Autocorr_test  \
# 0     const         5.016790e-52\nRUSSIA GDP    3.36...   0,247384083
# 1     const                     2.072923e-32\nUSA IN...    0,25306464
# 2     const                 3.127104e-39\nUSA INTERE...   0,245248955
# 3     const                        8.291935e-52\nUSA...   0,246417416
# 4     const               0.000942\nRUSSIA RTS INDEX...   0,255978607
# ...                                                 ...           ...
# 8186  const                     0.000524\nRUSSIA GDP...   0,786992383
# 8187  const                        0.000735\nRUSSIA ...   0,726203558
# 8188  const                        0.000612\nRUSSIA ...   0,779111842
# 8189  const                        3.852721e-04\nUSA...    0,80260694
# 8190  const                        0.000410\nRUSSIA ...    0,80211286
#
#       Hetero_test Multicollinearity_Fstat Multicollinearity_pvalue  \
# 0     0,591155433             0,931897259               0,33634468
# 1     0,087997119             4,389905656              0,038290994
# 2      0,01037135             0,174347526              0,677035343
# 3     0,570230002             0,113534844              0,736753661
# 4     0,314758261             3,160384616               0,07802131
# ...           ...                     ...                      ...
# 8186  0,004682886             8,829026241              1,64114E-11
# 8187  0,005577648             8,294761483               7,2274E-11
# 8188  0,017121577             9,223870327              5,61358E-12
# 8189  0,007323398             9,413821268              3,37319E-12
# 8190  0,007884552             8,618979908               1,0384E-11
#
#      Adjusted_R_squared
# 0           -0,00057262
# 1           0,027697592
# 2          -0,006986732
# 3          -0,007505195
# 4           0,017830784
# ...                 ...
# 8186        0,441178954
# 8187        0,423832434
# 8188        0,453342166
# 8189        0,459006945
# 8190        0,454245449
#
# [8191 rows x 10 columns]
#
#
# Data for Gold:
#       Line                             Variables_explicatives  \
# 0        0                                     ['RUSSIA GDP']
# 1        1                         ['USA INFLATION RATE CPI']
# 2        2                             ['USA INTEREST RATES']
# 3        3                      ['USA INDUSTRIAL PRODUCTION']
# 4        4                               ['RUSSIA RTS INDEX']
# ...    ...                                                ...
# 8186  8186  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8187  8187  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8188  8188  ['RUSSIA GDP', 'USA INTEREST RATES', 'USA INDU...
# 8189  8189  ['USA INFLATION RATE CPI', 'USA INTEREST RATES...
# 8190  8190  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
#
#                                            Coefficients  \
# 0     const         1446.062215\nRUSSIA GDP   -1085....
# 1     const                     1579.721148\nUSA INF...
# 2     const                 1546.361352\nUSA INTERES...
# 3     const                        1447.221197\nUSA ...
# 4     const               2047.744425\nRUSSIA RTS IN...
# ...                                                 ...
# 8186  const                      868.273590\nRUSSIA ...
# 8187  const                         874.368064\nRUSS...
# 8188  const                        1021.185352\nRUSS...
# 8189  const                        859.051118\nUSA I...
# 8190  const                         861.883480\nRUSS...
#
#                                        Erreurs_standard  \
# 0     const          24.696558\nRUSSIA GDP    713.80...
# 1     const                     33.786013\nUSA INFLA...
# 2     const                 31.475423\nUSA INTEREST ...
# 3     const                        24.931768\nUSA IN...
# 4     const               118.523814\nRUSSIA RTS IND...
# ...                                                 ...
# 8186  const                     218.270662\nRUSSIA G...
# 8187  const                        218.617536\nRUSSI...
# 8188  const                        240.449125\nRUSSI...
# 8189  const                        227.474840\nUSA I...
# 8190  const                        215.923309\nRUSSI...
#
#                                                 P-value Autocorr_test  \
# 0     const         4.734974e-89\nRUSSIA GDP    1.31...   0,064452482
# 1     const                     5.355630e-78\nUSA IN...   0,074754618
# 2     const                 2.066498e-80\nUSA INTERE...   0,068936475
# 3     const                        1.274175e-88\nUSA...   0,056462492
# 4     const               4.167933e-34\nRUSSIA RTS I...   0,104650678
# ...                                                 ...           ...
# 8186  const                     1.267160e-04\nRUSSIA...   0,457496462
# 8187  const                        1.170827e-04\nRUS...   0,413854647
# 8188  const                        4.635099e-05\nRUS...   0,500909408
# 8189  const                        0.000262\nUSA INF...   0,413091087
# 8190  const                        1.211668e-04\nRUS...   0,445853748
#
#       Hetero_test Multicollinearity_Fstat Multicollinearity_pvalue  \
# 0     0,002074963             2,311304134              0,131111321
# 1      7,2762E-06             27,63138968              6,61768E-07
# 2     1,48727E-07             21,28746628              1,01164E-05
# 3     0,449400625             0,107604563              0,743469299
# 4     0,610556418             26,65588753              9,97195E-07
# ...           ...                     ...                      ...
# 8186  0,003211948             18,97980318               2,3014E-21
# 8187  0,004450362             18,87400768              2,79574E-21
# 8188  0,002523354             13,64840735              1,10167E-16
# 8189  0,058091411             16,77429454               1,5444E-19
# 8190  0,009084124             18,16651151              2,12227E-21
#
#      Adjusted_R_squared
# 0            0,01089926
# 1           0,182868472
# 2           0,145651772
# 3          -0,007555783
# 4            0,17735806
# ...                 ...
# 8186         0,64451894
# 8187         0,64316567
# 8188        0,560530284
# 8189        0,614001727
# 8190        0,652214219
#
# [8191 rows x 10 columns]
#
#
# Data for Lead:
#       Line                             Variables_explicatives  \
# 0        0                                     ['RUSSIA GDP']
# 1        1                         ['USA INFLATION RATE CPI']
# 2        2                             ['USA INTEREST RATES']
# 3        3                      ['USA INDUSTRIAL PRODUCTION']
# 4        4                               ['RUSSIA RTS INDEX']
# ...    ...                                                ...
# 8186  8186  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8187  8187  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8188  8188  ['RUSSIA GDP', 'USA INTEREST RATES', 'USA INDU...
# 8189  8189  ['USA INFLATION RATE CPI', 'USA INTEREST RATES...
# 8190  8190  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
#
#                                            Coefficients  \
# 0     const         2067.865539\nRUSSIA GDP    1627....
# 1     const                     2039.076584\nUSA INF...
# 2     const                 1989.720419\nUSA INTERES...
# 3     const                        2066.234277\nUSA ...
# 4     const               2104.978318\nRUSSIA RTS IN...
# ...                                                 ...
# 8186  const                     1411.397565\nRUSSIA ...
# 8187  const                        1389.990360\nRUSS...
# 8188  const                        1478.275562\nRUSS...
# 8189  const                        1405.251144\nUSA ...
# 8190  const                        1406.503852\nRUSS...
#
#                                        Erreurs_standard  \
# 0     const          20.277226\nRUSSIA GDP    586.07...
# 1     const                     31.319098\nUSA INFLA...
# 2     const                 26.777164\nUSA INTEREST ...
# 3     const                        20.917696\nUSA IN...
# 4     const               110.077866\nRUSSIA RTS IND...
# ...                                                 ...
# 8186  const                     217.467167\nRUSSIA G...
# 8187  const                        222.001570\nRUSSI...
# 8188  const                        219.347540\nRUSSI...
# 8189  const                        218.014573\nUSA I...
# 8190  const                        216.522163\nRUSSI...
#
#                                                 P-value Autocorr_test  \
# 0     const         6.528452e-117\nRUSSIA GDP     6....   0,317567995
# 1     const                     2.516316e-94\nUSA IN...   0,305909205
# 2     const                 6.131380e-101\nUSA INTER...   0,347883837
# 3     const                        2.692235e-115\nUS...   0,300270535
# 4     const               5.984426e-38\nRUSSIA RTS I...   0,305084714
# ...                                                 ...           ...
# 8186  const                     2.745769e-09\nRUSSIA...   1,010655318
# 8187  const                        8.105148e-09\nRUS...   1,059181777
# 8188  const                        8.308337e-10\nRUS...    0,99501182
# 8189  const                        3.392557e-09\nUSA...   1,047804644
# 8190  const                        2.743155e-09\nRUS...   1,025256717
#
#       Hetero_test Multicollinearity_Fstat Multicollinearity_pvalue  \
# 0      0,20265943             7,707908956              0,006395982
# 1     0,004714292             1,374283507              0,243438608
# 2     0,661521277             17,55840596              5,40551E-05
# 3     0,390120112              0,18347005              0,669188772
# 4     0,691849941             0,126611302              0,722607094
# ...           ...                     ...                      ...
# 8186  0,339034354             10,87821831              7,65623E-14
# 8187   0,33187405             10,06600693              6,06329E-13
# 8188  0,086437107              10,1826585              4,48391E-13
# 8189  0,707075325             10,78379653              9,70199E-14
# 8190  0,366910682             10,28299546              1,06581E-13
#
#      Adjusted_R_squared
# 0           0,053361073
# 1           0,003135378
# 2           0,122149607
# 3          -0,006909003
# 4          -0,007393666
# ...                 ...
# 8186        0,499028831
# 8187        0,477593785
# 8188        0,480784448
# 8189        0,496627741
# 8190        0,503502479
#
# [8191 rows x 10 columns]
#
#
# Data for Live_Cattle:
#       Line                             Variables_explicatives  \
# 0        0                                     ['RUSSIA GDP']
# 1        1                         ['USA INFLATION RATE CPI']
# 2        2                             ['USA INTEREST RATES']
# 3        3                      ['USA INDUSTRIAL PRODUCTION']
# 4        4                               ['RUSSIA RTS INDEX']
# ...    ...                                                ...
# 8186  8186  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8187  8187  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8188  8188  ['RUSSIA GDP', 'USA INTEREST RATES', 'USA INDU...
# 8189  8189  ['USA INFLATION RATE CPI', 'USA INTEREST RATES...
# 8190  8190  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
#
#                                            Coefficients  \
# 0     const         128.232267\nRUSSIA GDP    145.92...
# 1     const                     118.502945\nUSA INFL...
# 2     const                 132.650349\nUSA INTEREST...
# 3     const                        128.042228\nUSA I...
# 4     const               70.918430\nRUSSIA RTS INDE...
# ...                                                 ...
# 8186  const                      11.666513\nRUSSIA G...
# 8187  const                         12.011971\nRUSSI...
# 8188  const                          1.015199\nRUSSI...
# 8189  const                        11.198371\nUSA IN...
# 8190  const                         11.376013\nRUSSI...
#
#                                        Erreurs_standard  \
# 0     const          1.670585\nRUSSIA GDP    48.2848...
# 1     const                     2.326304\nUSA INFLAT...
# 2     const                 2.298244\nUSA INTEREST R...
# 3     const                        1.723010\nUSA IND...
# 4     const               7.383113\nRUSSIA RTS INDEX...
# ...                                                 ...
# 8186  const                     13.176861\nRUSSIA GD...
# 8187  const                        13.219909\nRUSSIA...
# 8188  const                        14.842270\nRUSSIA...
# 8189  const                        13.874585\nUSA IN...
# 8190  const                        13.124487\nRUSSIA...
#
#                                                 P-value Autocorr_test  \
# 0     const         1.435677e-102\nRUSSIA GDP     3....   0,159446152
# 1     const                     3.489348e-82\nUSA IN...   0,170067822
# 2     const                 2.436681e-88\nUSA INTERE...   0,145172257
# 3     const                        6.069876e-101\nUS...   0,163387948
# 4     const               1.726469e-16\nRUSSIA RTS I...   0,305703601
# ...                                                 ...           ...
# 8186  const                     3.779378e-01\nRUSSIA...   0,893970581
# 8187  const                        3.655889e-01\nRUS...    0,91658433
# 8188  const                        9.455956e-01\nRUS...   0,765747922
# 8189  const                        4.213913e-01\nUSA...   0,797015934
# 8190  const                        3.880217e-01\nRUS...   0,863313726
#
#       Hetero_test Multicollinearity_Fstat Multicollinearity_pvalue  \
# 0     0,011223514             9,134123676              0,003077613
# 1     0,817652843             30,53060741              1,99293E-07
# 2     0,005095458             8,323161199              0,004654745
# 3     0,848347242             1,571659255              0,212444337
# 4     0,033791206             62,25538735              1,70983E-12
# ...           ...                     ...                      ...
# 8186  0,188699306             28,09476981              1,05789E-27
# 8187  0,107922388             27,83119294              1,53346E-27
# 8188  0,336976512             19,71867825               6,0262E-22
# 8189  0,196433847             24,47414906              2,19901E-25
# 8190  0,142322896             26,29273193              2,33156E-27
#
#      Adjusted_R_squared
# 0           0,063980648
# 1           0,198818331
# 2           0,057971643
# 3           0,004780893
# 4           0,339825557
# ...                 ...
# 8186        0,732064799
# 8187        0,730143013
# 8188        0,653691384
# 8189        0,703012147
# 8190        0,734259637
#
# [8191 rows x 10 columns]
#
#
# Data for Platinium:
#       Line                             Variables_explicatives  \
# 0        0                                     ['RUSSIA GDP']
# 1        1                         ['USA INFLATION RATE CPI']
# 2        2                             ['USA INTEREST RATES']
# 3        3                      ['USA INDUSTRIAL PRODUCTION']
# 4        4                               ['RUSSIA RTS INDEX']
# ...    ...                                                ...
# 8186  8186  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8187  8187  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8188  8188  ['RUSSIA GDP', 'USA INTEREST RATES', 'USA INDU...
# 8189  8189  ['USA INFLATION RATE CPI', 'USA INTEREST RATES...
# 8190  8190  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
#
#                                            Coefficients  \
# 0     const         1031.313749\nRUSSIA GDP    -559....
# 1     const                     865.155563\nUSA INFL...
# 2     const                 970.779081\nUSA INTEREST...
# 3     const                        1031.694346\nUSA ...
# 4     const               922.429200\nRUSSIA RTS IND...
# ...                                                 ...
# 8186  const                     429.506748\nRUSSIA G...
# 8187  const                        413.134932\nRUSSI...
# 8188  const                         302.954504\nRUSS...
# 8189  const                        427.976338\nUSA I...
# 8190  const                        428.578692\nRUSSI...
#
#                                        Erreurs_standard  \
# 0     const          17.388540\nRUSSIA GDP    502.58...
# 1     const                     16.466790\nUSA INFLA...
# 2     const                 22.522487\nUSA INTEREST ...
# 3     const                        17.482088\nUSA IN...
# 4     const               91.410885\nRUSSIA RTS INDE...
# ...                                                 ...
# 8186  const                     115.156243\nRUSSIA G...
# 8187  const                        125.469129\nRUSSI...
# 8188  const                        144.061446\nRUSSI...
# 8189  const                        116.123515\nUSA I...
# 8190  const                        115.578131\nRUSSI...
#
#                                                 P-value Autocorr_test  \
# 0     const         1.093108e-89\nRUSSIA GDP    2.68...   0,116241801
# 1     const                     1.059793e-83\nUSA IN...    0,29505566
# 2     const                 4.676429e-74\nUSA INTERE...   0,122846061
# 3     const                        1.933900e-89\nUSA...   0,105952426
# 4     const               1.219396e-17\nRUSSIA RTS I...   0,111270358
# ...                                                 ...           ...
# 8186  const                     3.085091e-04\nRUSSIA...   0,807620083
# 8187  const                        1.345193e-03\nRUS...    0,61399957
# 8188  const                        3.781486e-02\nRUS...   0,762851739
# 8189  const                        3.601078e-04\nUSA...   0,760996414
# 8190  const                        3.341600e-04\nRUS...   0,776774324
#
#       Hetero_test Multicollinearity_Fstat Multicollinearity_pvalue  \
# 0     0,463950658             1,237531192                0,2682086
# 1     0,020455235              183,211056              9,08641E-26
# 2     0,209610972             15,65415389              0,000130271
# 3     0,458678192             0,020473576              0,886466388
# 4     0,080235095             1,484471391              0,225506638
# ...           ...                     ...                      ...
# 8186   0,49654574             40,32411527              3,56363E-34
# 8187  0,053734284             32,53626461              2,89781E-30
# 8188  0,055391412             21,96833036              1,23399E-23
# 8189  0,301907091             39,51915593              8,45369E-34
# 8190  0,515206923             36,97969875              2,05659E-33
#
#      Adjusted_R_squared
# 0           0,001992084
# 1            0,60492818
# 2           0,109642338
# 3          -0,008299631
# 4           0,004054681
# ...                 ...
# 8186        0,798608668
# 8187        0,760772849
# 8188        0,678916379
# 8189        0,795261727
# 8190        0,797183089
#
# [8191 rows x 10 columns]
#
#
# Data for Sugar_11:
#       Line                             Variables_explicatives  \
# 0        0                                     ['RUSSIA GDP']
# 1        1                         ['USA INFLATION RATE CPI']
# 2        2                             ['USA INTEREST RATES']
# 3        3                      ['USA INDUSTRIAL PRODUCTION']
# 4        4                               ['RUSSIA RTS INDEX']
# ...    ...                                                ...
# 8186  8186  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8187  8187  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8188  8188  ['RUSSIA GDP', 'USA INTEREST RATES', 'USA INDU...
# 8189  8189  ['USA INFLATION RATE CPI', 'USA INTEREST RATES...
# 8190  8190  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
#
#                                            Coefficients  \
# 0     const         15.632888\nRUSSIA GDP    -6.4988...
# 1     const                     15.559990\nUSA INFLA...
# 2     const                 15.613968\nUSA INTEREST ...
# 3     const                        15.648874\nUSA IN...
# 4     const               13.191233\nRUSSIA RTS INDE...
# ...                                                 ...
# 8186  const                     -7.679063\nRUSSIA GD...
# 8187  const                        -7.726056\nRUSSIA...
# 8188  const                       -6.337662\nRUSSIA ...
# 8189  const                       -7.744758\nUSA INF...
# 8190  const                        -7.732251\nRUSSIA...
#
#                                        Erreurs_standard  \
# 0     const         0.296121\nRUSSIA GDP    8.558767...
# 1     const                     0.446685\nUSA INFLAT...
# 2     const                 0.407053\nUSA INTEREST R...
# 3     const                        0.29536\nUSA INDU...
# 4     const               1.545167\nRUSSIA RTS INDEX...
# ...                                                 ...
# 8186  const                      3.174150\nRUSSIA GD...
# 8187  const                         3.157180\nRUSSIA...
# 8188  const                         3.278331\nRUSSIA...
# 8189  const                        3.175603\nUSA INF...
# 8190  const                         3.173375\nRUSSIA...
#
#                                                 P-value Autocorr_test  \
# 0     const         6.153684e-84\nRUSSIA GDP    4.49...   0,141574163
# 1     const                     6.180720e-64\nUSA IN...   0,139168808
# 2     const                 1.779053e-68\nUSA INTERE...   0,139197852
# 3     const                        4.095348e-84\nUSA...   0,160753684
# 4     const               5.551128e-14\nRUSSIA RTS I...   0,150919869
# ...                                                 ...           ...
# 8186  const                     0.017239\nRUSSIA GDP...    0,62529716
# 8187  const                        0.016027\nRUSSIA ...   0,603726511
# 8188  const                        0.055854\nRUSSIA ...   0,560587144
# 8189  const                        0.016380\nUSA INF...   0,603079632
# 8190  const                        0.016492\nRUSSIA ...   0,604204098
#
#       Hetero_test Multicollinearity_Fstat Multicollinearity_pvalue  \
# 0     0,056511831             0,576572693              0,449173091
# 1     0,020124367             0,054927974              0,815106106
# 2     0,093069398             0,007594877              0,930701119
# 3     0,865892604             1,244565979               0,26685966
# 4     0,072464618             2,601876154              0,109408573
# ...           ...                     ...                      ...
# 8186  0,120417017             9,774761423              1,29681E-12
# 8187  0,125467146             9,964454522              7,89492E-13
# 8188  0,018895456             8,283592406              7,45778E-11
# 8189  0,143769223             9,762266396               1,3401E-12
# 8190  0,122895213             9,112698321               2,5702E-12
#
#      Adjusted_R_squared
# 0          -0,003570919
# 1          -0,008005359
# 2          -0,008409672
# 3           0,002050961
# 4           0,013282349
# ...                 ...
# 8186        0,469453772
# 8187        0,474784015
# 8188        0,423458296
# 8189         0,46909887
# 8190        0,469850718
#
# [8191 rows x 10 columns]
#
#
# Data for WTI:
#       Line                             Variables_explicatives  \
# 0        0                                     ['RUSSIA GDP']
# 1        1                         ['USA INFLATION RATE CPI']
# 2        2                             ['USA INTEREST RATES']
# 3        3                      ['USA INDUSTRIAL PRODUCTION']
# 4        4                               ['RUSSIA RTS INDEX']
# ...    ...                                                ...
# 8186  8186  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8187  8187  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8188  8188  ['RUSSIA GDP', 'USA INTEREST RATES', 'USA INDU...
# 8189  8189  ['USA INFLATION RATE CPI', 'USA INTEREST RATES...
# 8190  8190  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
#
#                                            Coefficients  \
# 0     const         65.080373\nRUSSIA GDP    20.0484...
# 1     const                     51.159095\nUSA INFLA...
# 2     const                 60.14698\nUSA INTEREST R...
# 3     const                        65.031657\nUSA IN...
# 4     const               57.813343\nRUSSIA RTS INDE...
# ...                                                 ...
# 8186  const                    -84.755985\nRUSSIA GD...
# 8187  const                       -84.469788\nRUSSIA...
# 8188  const                       -95.328284\nRUSSIA...
# 8189  const                       -85.262363\nUSA IN...
# 8190  const                       -85.230668\nRUSSIA...
#
#                                        Erreurs_standard  \
# 0     const          1.985936\nRUSSIA GDP    57.3994...
# 1     const                     2.451928\nUSA INFLAT...
# 2     const                 2.643297\nUSA INTEREST R...
# 3     const                        1.985306\nUSA IND...
# 4     const               10.434068\nRUSSIA RTS INDE...
# ...                                                 ...
# 8186  const                     14.646950\nRUSSIA GD...
# 8187  const                        14.574918\nRUSSIA...
# 8188  const                        15.900458\nRUSSIA...
# 8189  const                        14.393933\nUSA IN...
# 8190  const                        14.437454\nRUSSIA...
#
#                                                 P-value Autocorr_test  \
# 0     const         4.264747e-61\nRUSSIA GDP    7.27...   0,087943244
# 1     const                     2.092214e-41\nUSA IN...   0,133152995
# 2     const                 5.691490e-45\nUSA INTERE...   0,095709249
# 3     const                        4.465239e-61\nUSA...   0,091202383
# 4     const               1.858954e-07\nRUSSIA RTS I...   0,091248555
# ...                                                 ...           ...
# 8186  const                     7.237336e-08\nRUSSIA...   0,937196356
# 8187  const                        6.949286e-08\nRUS...   0,860245009
# 8188  const                        2.789536e-08\nRUS...   0,862059224
# 8189  const                        3.879451e-08\nUSA...   0,948977737
# 8190  const                        4.335603e-08\nRUS...   0,945473253
#
#       Hetero_test Multicollinearity_Fstat Multicollinearity_pvalue  \
# 0     0,011080297             0,121996059              0,727502134
# 1     0,172054778             57,54778981              8,35298E-12
# 2     0,295571561             7,384880515              0,007568346
# 3       0,1074459             0,252669153              0,616138732
# 4     0,224779799             0,500945987              0,480480396
# ...           ...                     ...                      ...
# 8186  0,562124602             30,41364385              4,48516E-29
# 8187  0,244234858             30,77859116              2,77256E-29
# 8188  0,300388883             23,84346601               5,8937E-25
# 8189   0,47217249             31,81853931              7,20484E-30
# 8190  0,413871665             29,22202794              3,50759E-29
#
#      Adjusted_R_squared
# 0          -0,007433027
# 1           0,322121913
# 2           0,050922252
# 3           -0,00631978
# 4          -0,004211393
# ...                 ...
# 8186        0,747861979
# 8187        0,750180067
# 8188        0,697294673
# 8189        0,756557837
# 8190        0,755086767
#
# [8191 rows x 10 columns]
#
#
# Data for Zinc:
#       Line                             Variables_explicatives  \
# 0        0                                     ['RUSSIA GDP']
# 1        1                         ['USA INFLATION RATE CPI']
# 2        2                             ['USA INTEREST RATES']
# 3        3                      ['USA INDUSTRIAL PRODUCTION']
# 4        4                               ['RUSSIA RTS INDEX']
# ...    ...                                                ...
# 8186  8186  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8187  8187  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
# 8188  8188  ['RUSSIA GDP', 'USA INTEREST RATES', 'USA INDU...
# 8189  8189  ['USA INFLATION RATE CPI', 'USA INTEREST RATES...
# 8190  8190  ['RUSSIA GDP', 'USA INFLATION RATE CPI', 'USA ...
#
#                                            Coefficients  \
# 0     const         2570.423278\nRUSSIA GDP    4608....
# 1     const                     2787.289280\nUSA INF...
# 2     const                 2641.756566\nUSA INTERES...
# 3     const                        2566.508532\nUSA ...
# 4     const               2705.305649\nRUSSIA RTS IN...
# ...                                                 ...
# 8186  const                      252.864711\nRUSSIA ...
# 8187  const                         271.180723\nRUSS...
# 8188  const                         645.189784\nRUSS...
# 8189  const                        236.527098\nUSA I...
# 8190  const                         240.380066\nRUSS...
#
#                                        Erreurs_standard  \
# 0     const           50.877304\nRUSSIA GDP    1470....
# 1     const                     74.924126\nUSA INFLA...
# 2     const                 71.907498\nUSA INTEREST ...
# 3     const                        52.963525\nUSA IN...
# 4     const               278.351269\nRUSSIA RTS IND...
# ...                                                 ...
# 8186  const                      461.543412\nRUSSIA ...
# 8187  const                         466.175684\nRUSS...
# 8188  const                         533.159987\nRUSS...
# 8189  const                        466.647261\nUSA I...
# 8190  const                         457.639705\nRUSS...
#
#                                                 P-value Autocorr_test  \
# 0     const         8.852446e-82\nRUSSIA GDP    2.17...   0,128664997
# 1     const                     5.022114e-67\nUSA IN...   0,128743421
# 2     const                 1.960660e-66\nUSA INTERE...   0,109300035
# 3     const                        9.707451e-80\nUSA...   0,105061556
# 4     const               9.298478e-17\nRUSSIA RTS I...     0,1053355
# ...                                                 ...           ...
# 8186  const                     5.849239e-01\nRUSSIA...   0,927183324
# 8187  const                        5.619832e-01\nRUS...   0,863575501
# 8188  const                        0.228898\nRUSSIA ...   0,821465716
# 8189  const                        6.132926e-01\nUSA...   0,978744621
# 8190  const                        6.004991e-01\nRUS...   0,972218131
#
#       Hetero_test Multicollinearity_Fstat Multicollinearity_pvalue  \
# 0     0,167837627              9,82004928              0,002177967
# 1     0,014184477             15,52216937               0,00013855
# 2     0,064039238             2,330218968              0,129560018
# 3     0,339549692             0,004382547              0,947329988
# 4      0,69715269             0,257531384              0,612768401
# ...           ...                     ...                      ...
# 8186  0,151949868              19,2141755              1,49917E-21
# 8187  0,028748372             18,64069953              4,30446E-21
# 8188  0,197016959             11,77692775              8,42828E-15
# 8189  0,209492038             18,60897886              4,56578E-21
# 8190  0,200828778              18,2648459              1,75729E-21
#
#      Adjusted_R_squared
# 0           0,069003645
# 1           0,108762234
# 2           0,011054737
# 3          -0,008437123
# 4          -0,006278404
# ...                 ...
# 8186        0,647480633
# 8187        0,640144613
# 8188        0,520785685
# 8189        0,639729914
# 8190         0,65350873
#
# [8191 rows x 10 columns]
